# %%
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import mysql.connector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4976/2006270917.py in <module>
#       1 import time
# ----> 2 from selenium import webdriver
#       3 from selenium.webdriver.chrome.service import Service
#       4 from webdriver_manager.chrome import ChromeDriverManager
#       5 from selenium.webdriver.chrome.options import Options
#
# ModuleNotFoundError: No module named 'selenium'

# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.18.1-py3-none-any.whl (10.0 MB)
# Collecting typing_extensions>=4.9.0
#   Downloading typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\cloud\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Collecting trio~=0.17
#   Downloading trio-0.25.0-py3-none-any.whl (467 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\cloud\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: sortedcontainers in c:\users\cloud\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting outcome
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: idna in c:\users\cloud\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Collecting attrs>=23.2.0
#   Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
# Requirement already satisfied: cffi>=1.14 in c:\users\cloud\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Collecting sniffio>=1.3.0
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: pycparser in c:\users\cloud\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\cloud\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: attrs, sniffio, outcome, h11, exceptiongroup, wsproto, trio, typing-extensions, trio-websocket, selenium
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.2.0
#     Uninstalling attrs-21.2.0:
#       Successfully uninstalled attrs-21.2.0
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
# Successfully installed attrs-23.2.0 exceptiongroup-1.2.0 h11-0.14.0 outcome-1.3.0.post0 selenium-4.18.1 sniffio-1.3.1 trio-0.25.0 trio-websocket-0.11.1 typing-extensions-4.10.0 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4976/1718976487.py in <module>
#       1 from selenium import webdriver
#       2 from selenium.webdriver.chrome.service import Service
# ----> 3 from webdriver_manager.chrome import ChromeDriverManager
#       4 from selenium.webdriver.chrome.options import Options
#       5 from selenium.webdriver.common.by import By
#
# ModuleNotFoundError: No module named 'webdriver_manager'

# %%
pip install webdriver_manager
# Out:
# Collecting webdriver_manager
#   Downloading webdriver_manager-4.0.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: requests in c:\users\cloud\anaconda3\lib\site-packages (from webdriver_manager) (2.26.0)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: packaging in c:\users\cloud\anaconda3\lib\site-packages (from webdriver_manager) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\cloud\anaconda3\lib\site-packages (from packaging->webdriver_manager) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\cloud\anaconda3\lib\site-packages (from requests->webdriver_manager) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cloud\anaconda3\lib\site-packages (from requests->webdriver_manager) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\cloud\anaconda3\lib\site-packages (from requests->webdriver_manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cloud\anaconda3\lib\site-packages (from requests->webdriver_manager) (3.2)
# Installing collected packages: python-dotenv, webdriver-manager
# Successfully installed python-dotenv-1.0.1 webdriver-manager-4.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver_path = ChromeDriverManager().install()
service = Service(driver_path)
driver = webdriver.Chrome(service=service, options=options)

driver.get('https://replicate.com/collections/text-to-image')
time.sleep(5)
body = driver.find_element(By.TAG_NAME, 'body')

soup = BeautifulSoup(body.get_attribute('innerHTML'), 'html.parser')
print(soup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10976/2373392675.py in <module>
#       1 driver_path = ChromeDriverManager().install()
# ----> 2 service = Service(driver_path)
#       3 driver = webdriver.Chrome(service=service, options=options)
#       4
#       5 driver.get('https://replicate.com/collections/text-to-image')
#
# NameError: name 'Service' is not defined

# %%
from selenium.webdriver.chrome.service import Service

# %%
driver_path = ChromeDriverManager().install()
service = Service(driver_path)
driver = webdriver.Chrome(service=service, options=options)

driver.get('https://replicate.com/collections/text-to-image')

time.sleep(5)
body = driver.find_element(By.TAG_NAME, 'body')

soup = BeautifulSoup(body.get_attribute('innerHTML'), 'html.parser')
print(soup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10976/4206119114.py in <module>
#       1 driver_path = ChromeDriverManager().install()
#       2 service = Service(driver_path)
# ----> 3 driver = webdriver.Chrome(service=service, options=options)
#       4
#       5 driver.get('https://replicate.com/collections/text-to-image')
#
# NameError: name 'webdriver' is not defined

# %%
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import json
import requests

# %%
options = Options()
options.add_argument("--disable-extensions")
options.add_argument("--ignore-certificate-errors")

driver_path = ChromeDriverManager().install()
service = Service(driver_path)
driver = webdriver.Chrome(service=service, options=options)

driver.get('https://replicate.com/collections/text-to-image')

time.sleep(5)
body = driver.find_element(By.TAG_NAME, 'body')

soup = BeautifulSoup(body.get_attribute('innerHTML'), 'html.parser')
print(soup)
# Out:
# <header class="bg-white md:bg-white/90 md:sticky top-0 z-10 p-6 md:mb-6 md:filter md:backdrop-blur" data-stuck="false" id="app-header">
# <div class="flex items-center justify-between gap-6">
# <div class="flex items-center gap-4">
# <h1 class="header-logo">
# <a class="no-focus no-outline focus:bg-black focus:text-white inline-flex p-1.5" href="/" title="Replicate">
# <div class="w-8 h-8 header-logo">
# <svg class="logo" fill="currentColor" version="1.1" viewbox="0 0 1000 1000" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g>
# <polygon points="1000,427.6 1000,540.6 603.4,540.6 603.4,1000 477,1000 477,427.6"></polygon>
# <polygon points="1000,213.8 1000,327 364.8,327 364.8,1000 238.4,1000 238.4,213.8"></polygon>
# <polygon points="1000,0 1000,113.2 126.4,113.2 126.4,1000 0,1000 0,0"></polygon>
# </g>
# </svg>
# </div>
# </a>
# </h1>
# </div>
# <div class="flex-shrink-0">
# <div class="hidden md:block">
# <nav class="flex justify-end items-start">
# <div class="flex flex-wrap">
# <a class="nav-link selected" href="/explore">Explore</a>
# <a class="nav-link" href="/pricing">Pricing</a>
# <a class="nav-link" href="/docs">Docs</a>
# <a class="nav-link" href="/blog">Blog</a>
# <a class="nav-link" href="/changelog">Changelog</a>
# <a class="nav-link" href="/signin?next=/collections/text-to-image">Sign in</a>
# <a class="nav-link-primary" href="/docs">Get started</a>
# </div>
# </nav>
# </div>
# <div class="block md:hidden"><script id="react-component-props-7194af13-4662-40d2-97ad-517cf9264705" type="application/json">{"isAuthenticated": false}</script>
# <div data-component="MobileMenu" data-props="react-component-props-7194af13-4662-40d2-97ad-517cf9264705"><button aria-controls=":r0:" aria-expanded="false" class="r8-btn r8-btn--outlined r8-btn--primary r8-btn--sm r8-disclosure" type="button"><span class="r8-btn__icon"><svg fill="currentColor" height="1em" viewbox="0 0 256 256" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M224,128a8,8,0,0,1-8,8H40a8,8,0,0,1,0-16H216A8,8,0,0,1,224,128ZM40,72H216a8,8,0,0,0,0-16H40a8,8,0,0,0,0,16ZM216,184H40a8,8,0,0,0,0,16H216a8,8,0,0,0,0-16Z"></path></svg></span>Menu</button></div>
# </div>
# </div>
# </div>
# </header>
# <div class="mb-6 md:mb-0 md:hidden" id="js-mobile-menu"><div><div class="px-6 bg-r8-gray-1 border-b border-r8-gray-6" hidden="" id=":r0:" style="display: none;"><nav class="flex flex-col divide-y divide-r8-gray-4 py-2"><a class="block no-default no-focus px-2 py-2.5 no-underline text-r8-gray-11 hover:text-r8-gray-12 text-r8-sm" href="/explore">Explore</a><a class="block no-default no-focus px-2 py-2.5 no-underline text-r8-gray-11 hover:text-r8-gray-12 text-r8-sm" href="/pricing">Pricing</a><a class="block no-default no-focus px-2 py-2.5 no-underline text-r8-gray-11 hover:text-r8-gray-12 text-r8-sm" href="/docs">Docs</a><a class="block no-default no-focus px-2 py-2.5 no-underline text-r8-gray-11 hover:text-r8-gray-12 text-r8-sm" href="/blog">Blog</a><a class="block no-default no-focus px-2 py-2.5 no-underline text-r8-gray-11 hover:text-r8-gray-12 text-r8-sm" href="/changelog">Changelog</a><a class="bg-r8-gray-12 text-r8-gray-1 px-2 py-2.5 text-center no-focus" href="/signin">Sign in</a></nav></div></div></div>
# <main class="layout-main flex-1">
# <div>
# <a class="no-outline no-default text-r8-gray-10 text-r8-sm inline-block mb-3" href="/explore#collections">
# <svg class="icon" fill="none" height="24" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><rect height="7" width="7" x="3" y="3"></rect><rect height="7" width="7" x="14" y="3"></rect><rect height="7" width="7" x="14" y="14"></rect><rect height="7" width="7" x="3" y="14"></rect></svg>
#     Collections
#   </a>
# </div>
# <h1 class="mb-lh">Generate images</h1>
# <div class="grid grid-cols-12 gap-4 lg:gap-8 xl:gap-10">
# <div class="col-span-full lg:col-span-5">
# <div class="sticky top-32">
# <div class="markdown">
# <p>These models generate images from text prompts. Many of these models are based on Stable Diffusion.</p>
# <p><a href="https://replicate.com/guides/stable-diffusion" rel="nofollow">Read our guide</a> to learn more about using Stable Diffusion.</p>
# <ul>
# <li><strong>Text-to-image</strong> - Convert text prompts to photorealistic images. Useful for quickly visualizing concepts</li>
# <li><strong>Control over style</strong> - Adjust image properties like lighting and texture via prompts</li>
# <li><strong>In-painting</strong> - Expand, edit, or refine images by filling in missing regions</li>
# </ul>
# <h2 id="our-picks">Our Picks</h2>
# <h2 id="best-overall-image-generation-model-stability-aisdxl"><strong>Best overall image generation model: <a href="https://replicate.com/stability-ai/sdxl" rel="nofollow">stability-ai/sdxl</a></strong></h2>
# <p>The best overall image generation model is <a href="https://replicate.com/stability-ai/sdxl" rel="nofollow">stability-ai/sdxl</a>. It supports LoRA fine-tuning, which means you can customize the model to produce specific styles or subjects. For more information about how to fine-tune SDXL, read our <a href="https://replicate.com/guides/stable-diffusion/fine-tuning" rel="nofollow">detailed guide about fine-tuning Stable Diffusion</a></p>
# <h2 id="best-comfyui-model-fofrany-comfyui-workflow"><strong>Best ComfyUI model: <a href="https://replicate.com/fofr/any-comfyui-workflow" rel="nofollow">fofr/any-comfyui-workflow</a></strong></h2>
# <p>If you’re a fan of <a href="https://github.com/comfyanonymous/ComfyUI" rel="nofollow">ComfyUI</a>, you can export any of your favorite ComfyUI workflows to JSON and run them on Replicate using the <a href="https://replicate.com/fofr/any-comfyui-workflow" rel="nofollow">fofr/any-comfyui-workflow</a> model. For more information, check out our <a href="https://replicate.com/guides/comfyui" rel="nofollow">detailed guide to using ComfyUI</a>. </p>
# <h2 id="best-fast-image-generation-model-lucatacosdxl-lightning-4step"><strong>Best fast image generation model: <a href="https://replicate.com/lucataco/sdxl-lightning-4step" rel="nofollow">lucataco/sdxl-lightning-4step</a></strong></h2>
# <p>The best-looking fast image generation model is <a href="https://replicate.com/lucataco/sdxl-lightning-4step" rel="nofollow">lucataco/sdxl-lightning-4step</a>, it will spit out an image in 1.6 seconds. The fastest image generation model is <a href="https://replicate.com/fofr/latent-consistency-model" rel="nofollow">fofr/latent-consistency-model</a> which will generate an image in 0.6 seconds.</p>
# <h2 id="best-fine-tunes"><strong>Best fine-tunes</strong></h2>
# <p>Make sure to check out our <a href="https://replicate.com/collections/sdxl-fine-tunes" rel="nofollow">SDXL fine-tunes collection</a>, which includes all publicly available SDXL fine-tunes hosted on Replicate. This collection should help you get a feel for the sorts of things you can do with fine-tuning.</p>
# </div>
# </div>
# </div>
# <div class="col-span-full lg:col-span-7">
# <div>
# <p class="uppercase text-r8-sm tracking-wider mb-4 text-r8-gray-11">Recommended models</p>
# <div class="grid grid-cols-1 lg:grid-cols-2 grid-flow-row auto-rows-max gap-8">
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/stability-ai/stable-diffusion" title="stability-ai/stable-diffusion">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy entered loaded" data-ll-status="loaded" data-src="https://tjzk.replicate.delivery/models_models_featured_image/710f5e9f-9561-4e4f-9d1e-614205f62597/stable-diffusion.webp" role="presentation" src="https://tjzk.replicate.delivery/models_models_featured_image/710f5e9f-9561-4e4f-9d1e-614205f62597/stable-diffusion.webp"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">stability-ai</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">stable-diffusion</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           A latent text-to-image diffusion model capable of generating photo-realistic images given any text input
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  107.5M runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/stability-ai/sdxl" title="stability-ai/sdxl">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy entered loaded" data-ll-status="loaded" data-src="https://tjzk.replicate.delivery/models_models_featured_image/9065f9e3-40da-4742-8cb8-adfa8e794c0d/sdxl_cover.jpg" role="presentation" src="https://tjzk.replicate.delivery/models_models_featured_image/9065f9e3-40da-4742-8cb8-adfa8e794c0d/sdxl_cover.jpg"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">stability-ai</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">sdxl</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           A text-to-image generative AI model that creates beautiful images
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  45M runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/stability-ai/stable-diffusion-inpainting" title="stability-ai/stable-diffusion-inpainting">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy entered loaded" data-ll-status="loaded" data-src="https://replicate.delivery/pbxt/xs0pPOUM6HKmPlJJBXqKfE1YsiMzgNsCuGedlX0VqvPYifLgA/out-0.png" role="presentation" src="https://replicate.delivery/pbxt/xs0pPOUM6HKmPlJJBXqKfE1YsiMzgNsCuGedlX0VqvPYifLgA/out-0.png"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">stability-ai</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">stable-diffusion-inpainting</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Fill in masked parts of images with Stable Diffusion
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  16.3M runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/ai-forever/kandinsky-2.2" title="ai-forever/kandinsky-2.2">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy entered loaded" data-ll-status="loaded" data-src="https://tjzk.replicate.delivery/models_models_featured_image/618e68d3-fba3-4fd0-a060-cdd46b2ab7cf/out-0_2.jpg" role="presentation" src="https://tjzk.replicate.delivery/models_models_featured_image/618e68d3-fba3-4fd0-a060-cdd46b2ab7cf/out-0_2.jpg"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">ai-forever</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">kandinsky-2.2</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           multilingual text2image latent diffusion model
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  8.1M runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/ai-forever/kandinsky-2" title="ai-forever/kandinsky-2">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/e58cec51-6215-4d30-8c03-80f3ea0994d0/einstein.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">ai-forever</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">kandinsky-2</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           text2img model trained on LAION HighRes and fine-tuned on internal datasets
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  5.9M runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/fofr/sdxl-emoji" title="fofr/sdxl-emoji">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/8629c6ba-b94c-4cbd-93aa-bda2b8ebecd9/F5Mg2KeXgAAkfre.jpg" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">fofr</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">sdxl-emoji</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           An SDXL fine-tune based on Apple Emojis
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  3.6M runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/tstramer/material-diffusion" title="tstramer/material-diffusion">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/XcklpSF1o7Z1I91xQQQHFvJfltWEa3HuQpoeVVTvN7GVJhffA/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">tstramer</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">material-diffusion</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Stable diffusion fork for generating tileable outputs using v1.5 model
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  2.1M runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/bytedance/sdxl-lightning-4step" title="bytedance/sdxl-lightning-4step">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/779f3f58-c3db-4403-a01b-3ffed97a1449/out-0-1.jpg" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">bytedance</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">sdxl-lightning-4step</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           SDXL-Lightning by ByteDance: a fast text-to-image model that makes high-quality images in 4 steps
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  1.3M runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/lucataco/ssd-1b" title="lucataco/ssd-1b">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/82a7b2d0-d2bf-4ccd-bbe7-6a9ddbd44774/out-0-33.webp" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">lucataco</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">ssd-1b</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Segmind Stable Diffusion Model (SSD-1B) is a distilled 50% smaller version of SDXL, offering a 60% speedup while maintaining high-quality text-to-image generation capabilities
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  797K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/fofr/latent-consistency-model" title="fofr/latent-consistency-model">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/859c8ec6-4046-4d4e-9826-b7b575e5b79f/cover.webp" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">fofr</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">latent-consistency-model</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Super-fast, 0.6s per image. LCM with img2img, large batching and canny controlnet
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  738.4K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/batouresearch/sdxl-controlnet-lora" title="batouresearch/sdxl-controlnet-lora">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/oDtYIK2lDoaKMtdE4E5ozQSa61BU3gc4aRvGF3xmFpdwCxbE/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">batouresearch</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">sdxl-controlnet-lora</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           '''Last update: Now supports img2img.''' SDXL Canny controlnet with LoRA support.
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  320.7K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/lucataco/proteus-v0.2" title="lucataco/proteus-v0.2">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/1nrcrEszpsb0Kpv0qNBJrtQjoefjHJ3xSh3whVOJcklSFxPSA/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">lucataco</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">proteus-v0.2</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Proteus v0.2 shows subtle yet significant improvements over Version 0.1. It demonstrates enhanced prompt understanding that surpasses MJ6, while also approaching its stylistic capabilities.
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  257K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/playgroundai/playground-v2-1024px-aesthetic" title="playgroundai/playground-v2-1024px-aesthetic">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/e61adb01-bb73-448f-b2d5-3e8827577128/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">playgroundai</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">playground-v2-1024px-aesthetic</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Playground v2 is a diffusion-based text-to-image generative model trained from scratch by the research team at Playground
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  221.9K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/lucataco/realvisxl-v2.0" title="lucataco/realvisxl-v2.0">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/eCTbwmWQ00UbQiZdRMfgLhTRIKFUkBPei9fOQ2taGKw3NpaHB/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">lucataco</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">realvisxl-v2.0</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Implementation of SDXL RealVisXL_V2.0
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  220.9K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/lucataco/realvisxl2-lcm" title="lucataco/realvisxl2-lcm">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/ILTzFdAenk1JLKVb7jZbEDUOUJGz7hSFFSArhCnxin7ICY8IA/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">lucataco</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">realvisxl2-lcm</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           RealvisXL-v2.0 with LCM LoRA - requires fewer steps (4 to 8 instead of the original 40 to 50)
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  211.5K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/fofr/realvisxl-v3-multi-controlnet-lora" title="fofr/realvisxl-v3-multi-controlnet-lora">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/mUtp8mKk8yI0EJ5olzsnpkeTbAcmy2OTEqnXXc8EFGLhhuEJA/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">fofr</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">realvisxl-v3-multi-controlnet-lora</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           RealVisXl V3 with multi-controlnet, lora loading, img2img, inpainting
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  137.4K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/fofr/sdxl-multi-controlnet-lora" title="fofr/sdxl-multi-controlnet-lora">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/GR5kmreA4fjf9JZIFh0GhIoEGEnJj6SmwYTszYVezXWm7EpHB/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">fofr</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">sdxl-multi-controlnet-lora</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Multi-controlnet, lora loading, img2img, inpainting
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  136K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/fofr/sticker-maker" title="fofr/sticker-maker">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/fb7cf2ea-aacd-458d-9d19-76dda21f9748/sticker-maker.webp" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# ...
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  8.5K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/adirik/realvisxl-v4.0" title="adirik/realvisxl-v4.0">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/koQLfGV4o8yWGi4reeIvJQwCxmxrD3S7iQFGre8IfISrpnCTC/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">adirik</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">realvisxl-v4.0</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Photorealism with RealVisXL V4.0
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  7.3K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/fofr/txt2img" title="fofr/txt2img">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/jPiwHtgNYgrFPtoXfJeeWKiDRX6sGfyCp3c8yXEZBobevNASC/ComfyUI_00001_.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">fofr</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">txt2img</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Many models: RealVisXL, Juggernaut, Proteus, DreamShaper, etc.
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  6.7K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/adirik/kosmos-g" title="adirik/kosmos-g">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/aYXKkkuCWM6WN96DfeKBlVFTle875XmLLmMkJFp7rkNryqfHB/0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">adirik</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">kosmos-g</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Kosmos-G: Generating Images in Context with Multimodal Large Language Models
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  3.2K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/lucataco/sdxl-deepcache" title="lucataco/sdxl-deepcache">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/cj5eFwQqZPwROSKox75sbAVEJvfs58GX2Tswlu5tYzWwdLKSA/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">lucataco</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">sdxl-deepcache</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           SDXL using DeepCache
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  3K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/adirik/masactrl-sdxl" title="adirik/masactrl-sdxl">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/09z14i0H7QZhDtBvCnC1WtH05GpU60ZEliQ3ZNRW4WqEf9fRA/output1.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">adirik</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">masactrl-sdxl</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Editable image generation with MasaCtrl-SDXL
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  2.9K runs
#       </div>
# </div>
# </div>
# </a>
# <a class="no-default flex flex-col group border border-black focus:bg-black" href="/lucataco/playground-v2" title="lucataco/playground-v2">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/BdCKezxEeWgtLEtRdeCKrgyMg6ekeEFv8XYcM1khNUfgf1ffjA/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">lucataco</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">playground-v2</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Playground v2 is a diffusion-based text-to-image generative model trained from scratch. Try out all 3 models here
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  2.2K runs
#       </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </main>
# <div class="layout-footer">
# <footer class="flex flex-col md:flex-row gap-lh justify-between">
# <div class="flex items-center gap-3 overflow-hidden">
# <a class="flex-shrink-0" href="/">Replicate</a>
# <div class="flex-1">
# <iframe frameborder="0" height="30" scrolling="no" src="https://replicatestatus.com/badge" width="100%"></iframe>
# </div>
# </div>
# <div class="flex flex-wrap gap-05lh">
# <a href="/about">About</a>
# <a href="/guides">Guides</a>
# <a href="/terms">Terms</a>
# <a href="/privacy">Privacy</a>
# <a href="https://replicatestatus.com/">Status</a>
# <a href="https://github.com/replicate" translate="no">GitHub</a>
# <a href="https://x.com/replicate" translate="no">X</a>
# <a href="https://discord.gg/replicate" translate="no">Discord</a>
# <a href="/support">Support</a>
# </div>
# </footer>
# </div>
# <script nonce="">
#     window.VIDEOJS_NO_DYNAMIC_STYLE = true;
#
#   </script>
# <script nonce="">
#     const header = document.getElementById("app-header");
#
#     function monitorHeaderStickiness() {
#       if (header) {
#         header.setAttribute("data-stuck", window.scrollY > 0);
#       }
#     }
#
#     monitorHeaderStickiness();
#
#     document.addEventListener("scroll", (event) => {
#       monitorHeaderStickiness();
#     });
#
#   </script>

# %%
def initialize_driver():
    options = Options()
    options.add_argument("--disable-extensions")
    options.add_argument("--ignore-certificate-errors")

    driver_path = ChromeDriverManager().install()
    service = Service(driver_path)
    driver = webdriver.Chrome(service=service, options=options)
     
    return driver

# %%
def goToPage(driver, url):
    driver.get(url)
    time.sleep(5)
    body = driver.find_element(By.TAG_NAME, 'body')
    soup = BeautifulSoup(body.get_attribute('innerHTML'), 'html.parser')
    return soup

# %%
def main():
    driver = initialize_driver()
    url = 'https://replicate.com/collections/text-to-image'
    soup = goToPage(driver, url)
    time.sleep(10)
    models_list = soup.select('div.grid.grid-cols-1.lg\:grid-cols-2.grid-flow-row.auto-rows-max.gap-8 a')
    print(models_list)
    driver.quit()

# %%
main()
# Out:
# [<a class="no-default flex flex-col group border border-black focus:bg-black" href="/stability-ai/stable-diffusion" title="stability-ai/stable-diffusion">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy entered loaded" data-ll-status="loaded" data-src="https://tjzk.replicate.delivery/models_models_featured_image/710f5e9f-9561-4e4f-9d1e-614205f62597/stable-diffusion.webp" role="presentation" src="https://tjzk.replicate.delivery/models_models_featured_image/710f5e9f-9561-4e4f-9d1e-614205f62597/stable-diffusion.webp"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">stability-ai</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">stable-diffusion</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           A latent text-to-image diffusion model capable of generating photo-realistic images given any text input
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  107.5M runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/stability-ai/sdxl" title="stability-ai/sdxl">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy entered loaded" data-ll-status="loaded" data-src="https://tjzk.replicate.delivery/models_models_featured_image/9065f9e3-40da-4742-8cb8-adfa8e794c0d/sdxl_cover.jpg" role="presentation" src="https://tjzk.replicate.delivery/models_models_featured_image/9065f9e3-40da-4742-8cb8-adfa8e794c0d/sdxl_cover.jpg"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">stability-ai</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">sdxl</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           A text-to-image generative AI model that creates beautiful images
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  45M runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/stability-ai/stable-diffusion-inpainting" title="stability-ai/stable-diffusion-inpainting">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy entered loaded" data-ll-status="loaded" data-src="https://replicate.delivery/pbxt/xs0pPOUM6HKmPlJJBXqKfE1YsiMzgNsCuGedlX0VqvPYifLgA/out-0.png" role="presentation" src="https://replicate.delivery/pbxt/xs0pPOUM6HKmPlJJBXqKfE1YsiMzgNsCuGedlX0VqvPYifLgA/out-0.png"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">stability-ai</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">stable-diffusion-inpainting</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Fill in masked parts of images with Stable Diffusion
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  16.3M runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/ai-forever/kandinsky-2.2" title="ai-forever/kandinsky-2.2">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy entered loaded" data-ll-status="loaded" data-src="https://tjzk.replicate.delivery/models_models_featured_image/618e68d3-fba3-4fd0-a060-cdd46b2ab7cf/out-0_2.jpg" role="presentation" src="https://tjzk.replicate.delivery/models_models_featured_image/618e68d3-fba3-4fd0-a060-cdd46b2ab7cf/out-0_2.jpg"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">ai-forever</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">kandinsky-2.2</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           multilingual text2image latent diffusion model
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  8.1M runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/ai-forever/kandinsky-2" title="ai-forever/kandinsky-2">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/e58cec51-6215-4d30-8c03-80f3ea0994d0/einstein.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">ai-forever</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">kandinsky-2</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           text2img model trained on LAION HighRes and fine-tuned on internal datasets
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  5.9M runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/fofr/sdxl-emoji" title="fofr/sdxl-emoji">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/8629c6ba-b94c-4cbd-93aa-bda2b8ebecd9/F5Mg2KeXgAAkfre.jpg" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">fofr</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">sdxl-emoji</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           An SDXL fine-tune based on Apple Emojis
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  3.6M runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/tstramer/material-diffusion" title="tstramer/material-diffusion">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/XcklpSF1o7Z1I91xQQQHFvJfltWEa3HuQpoeVVTvN7GVJhffA/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">tstramer</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">material-diffusion</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Stable diffusion fork for generating tileable outputs using v1.5 model
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  2.1M runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/bytedance/sdxl-lightning-4step" title="bytedance/sdxl-lightning-4step">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/779f3f58-c3db-4403-a01b-3ffed97a1449/out-0-1.jpg" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">bytedance</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">sdxl-lightning-4step</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           SDXL-Lightning by ByteDance: a fast text-to-image model that makes high-quality images in 4 steps
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  1.3M runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/lucataco/ssd-1b" title="lucataco/ssd-1b">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/82a7b2d0-d2bf-4ccd-bbe7-6a9ddbd44774/out-0-33.webp" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">lucataco</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">ssd-1b</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Segmind Stable Diffusion Model (SSD-1B) is a distilled 50% smaller version of SDXL, offering a 60% speedup while maintaining high-quality text-to-image generation capabilities
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  797.1K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/fofr/latent-consistency-model" title="fofr/latent-consistency-model">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/859c8ec6-4046-4d4e-9826-b7b575e5b79f/cover.webp" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">fofr</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">latent-consistency-model</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Super-fast, 0.6s per image. LCM with img2img, large batching and canny controlnet
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  738.5K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/batouresearch/sdxl-controlnet-lora" title="batouresearch/sdxl-controlnet-lora">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/oDtYIK2lDoaKMtdE4E5ozQSa61BU3gc4aRvGF3xmFpdwCxbE/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">batouresearch</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">sdxl-controlnet-lora</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           '''Last update: Now supports img2img.''' SDXL Canny controlnet with LoRA support.
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  320.8K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/lucataco/proteus-v0.2" title="lucataco/proteus-v0.2">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/1nrcrEszpsb0Kpv0qNBJrtQjoefjHJ3xSh3whVOJcklSFxPSA/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">lucataco</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">proteus-v0.2</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Proteus v0.2 shows subtle yet significant improvements over Version 0.1. It demonstrates enhanced prompt understanding that surpasses MJ6, while also approaching its stylistic capabilities.
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  257.1K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/playgroundai/playground-v2-1024px-aesthetic" title="playgroundai/playground-v2-1024px-aesthetic">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/e61adb01-bb73-448f-b2d5-3e8827577128/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">playgroundai</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">playground-v2-1024px-aesthetic</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Playground v2 is a diffusion-based text-to-image generative model trained from scratch by the research team at Playground
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  221.9K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/lucataco/realvisxl-v2.0" title="lucataco/realvisxl-v2.0">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/eCTbwmWQ00UbQiZdRMfgLhTRIKFUkBPei9fOQ2taGKw3NpaHB/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">lucataco</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">realvisxl-v2.0</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Implementation of SDXL RealVisXL_V2.0
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  220.9K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/lucataco/realvisxl2-lcm" title="lucataco/realvisxl2-lcm">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/ILTzFdAenk1JLKVb7jZbEDUOUJGz7hSFFSArhCnxin7ICY8IA/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">lucataco</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">realvisxl2-lcm</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           RealvisXL-v2.0 with LCM LoRA - requires fewer steps (4 to 8 instead of the original 40 to 50)
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  211.6K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/fofr/realvisxl-v3-multi-controlnet-lora" title="fofr/realvisxl-v3-multi-controlnet-lora">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/mUtp8mKk8yI0EJ5olzsnpkeTbAcmy2OTEqnXXc8EFGLhhuEJA/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">fofr</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">realvisxl-v3-multi-controlnet-lora</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           RealVisXl V3 with multi-controlnet, lora loading, img2img, inpainting
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  137.5K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/fofr/sdxl-multi-controlnet-lora" title="fofr/sdxl-multi-controlnet-lora">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/GR5kmreA4fjf9JZIFh0GhIoEGEnJj6SmwYTszYVezXWm7EpHB/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">fofr</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">sdxl-multi-controlnet-lora</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Multi-controlnet, lora loading, img2img, inpainting
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  136K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/fofr/sticker-maker" title="fofr/sticker-maker">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/fb7cf2ea-aacd-458d-9d19-76dda21f9748/sticker-maker.webp" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">fofr</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">sticker-maker</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Make stickers with AI. Generates graphics with transparent backgrounds.
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  103.7K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/lucataco/dreamshaper-xl-turbo" title="lucataco/dreamshaper-xl-turbo">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/VHFfxS2zJYVMVy4Itjzw4ChNdQtEah9wkcUvyPDcPud72eDSA/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">lucataco</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">dreamshaper-xl-turbo</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           DreamShaper is a general purpose SD model that aims at doing everything well, photos, art, anime, manga. It's designed to match Midjourney and DALL-E.
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  97.2K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/playgroundai/playground-v2.5-1024px-aesthetic" title="playgroundai/playground-v2.5-1024px-aesthetic">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/b849582a-8699-4965-8016-3a51dc1da3d4/playground.jpeg" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">playgroundai</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">playground-v2.5-1024px-aesthetic</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Playground v2.5 is the state-of-the-art open-source model in aesthetic quality
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  96.6K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/fofr/any-comfyui-workflow" title="fofr/any-comfyui-workflow">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_featured_image/b7f3dda4-03ee-4dc0-b854-d8f740c153d6/cover.a1ee0b3e.jpg" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">fofr</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">any-comfyui-workflow</span>
# </h4>
# ...
# </svg>
#  8.6K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/lucataco/realistic-vision-v5" title="lucataco/realistic-vision-v5">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://tjzk.replicate.delivery/models_models_cover_image/1fa674fa-a368-4c79-bb00-6cd39e6faac4/output.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">lucataco</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">realistic-vision-v5</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Realistic Vision v5.0 with VAE
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  8.5K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/adirik/realvisxl-v4.0" title="adirik/realvisxl-v4.0">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/koQLfGV4o8yWGi4reeIvJQwCxmxrD3S7iQFGre8IfISrpnCTC/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">adirik</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">realvisxl-v4.0</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Photorealism with RealVisXL V4.0
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  7.3K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/fofr/txt2img" title="fofr/txt2img">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/jPiwHtgNYgrFPtoXfJeeWKiDRX6sGfyCp3c8yXEZBobevNASC/ComfyUI_00001_.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">fofr</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">txt2img</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Many models: RealVisXL, Juggernaut, Proteus, DreamShaper, etc.
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  6.7K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/adirik/kosmos-g" title="adirik/kosmos-g">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/aYXKkkuCWM6WN96DfeKBlVFTle875XmLLmMkJFp7rkNryqfHB/0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">adirik</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">kosmos-g</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Kosmos-G: Generating Images in Context with Multimodal Large Language Models
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  3.2K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/lucataco/sdxl-deepcache" title="lucataco/sdxl-deepcache">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/cj5eFwQqZPwROSKox75sbAVEJvfs58GX2Tswlu5tYzWwdLKSA/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">lucataco</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">sdxl-deepcache</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           SDXL using DeepCache
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  3K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/adirik/masactrl-sdxl" title="adirik/masactrl-sdxl">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/09z14i0H7QZhDtBvCnC1WtH05GpU60ZEliQ3ZNRW4WqEf9fRA/output1.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">adirik</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">masactrl-sdxl</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Editable image generation with MasaCtrl-SDXL
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  2.9K runs
#       </div>
# </div>
# </div>
# </a>, <a class="no-default flex flex-col group border border-black focus:bg-black" href="/lucataco/playground-v2" title="lucataco/playground-v2">
# <div class="h-80 group-focus:ring flex-shrink-0 bg-r8-gray-3">
# <div class="h-full w-full overflow-hidden">
# <img alt="" class="object-cover object-center w-full h-full lazy" data-src="https://replicate.delivery/pbxt/BdCKezxEeWgtLEtRdeCKrgyMg6ekeEFv8XYcM1khNUfgf1ffjA/out-0.png" role="presentation"/>
# </div>
# </div>
# <div class="flex-1">
# <div class="p-3 h-full flex flex-col justify-between">
# <div>
# <h4 class="inline-block group-focus:bg-black" translate="no">
# <span class="text-r8-gray-10 group-focus:text-white">lucataco</span><span class="text-r8-gray-10 group-focus:text-white px-1">/</span><span class="font-semibold text-r8-gray-12 group-focus:text-white">playground-v2</span>
# </h4>
# <p class="mt-2 text-r8-sm text-r8-gray-12 group-focus:text-white">
#           Playground v2 is a diffusion-based text-to-image generative model trained from scratch. Try out all 3 models here
#         </p>
# </div>
# <div class="text-r8-sm mt-4 text-branding-red">
# <svg class="icon" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M20.322.75a10.75 10.75 0 00-7.373 2.926l-1.304 1.23A23.743 23.743 0 0010.103 6.5H5.066a1.75 1.75 0 00-1.5.85l-2.71 4.514a.75.75 0 00.49 1.12l4.571.963c.039.049.082.096.129.14L8.04 15.96l1.872 1.994c.044.047.091.09.14.129l.963 4.572a.75.75 0 001.12.488l4.514-2.709a1.75 1.75 0 00.85-1.5v-5.038a23.741 23.741 0 001.596-1.542l1.228-1.304a10.75 10.75 0 002.925-7.374V2.499A1.75 1.75 0 0021.498.75h-1.177zM16 15.112c-.333.248-.672.487-1.018.718l-3.393 2.262.678 3.223 3.612-2.167a.25.25 0 00.121-.214v-3.822zm-10.092-2.7L8.17 9.017c.23-.346.47-.685.717-1.017H5.066a.25.25 0 00-.214.121l-2.167 3.612 3.223.679zm8.07-7.644a9.25 9.25 0 016.344-2.518h1.177a.25.25 0 01.25.25v1.176a9.25 9.25 0 01-2.517 6.346l-1.228 1.303a22.248 22.248 0 01-3.854 3.257l-3.288 2.192-1.743-1.858a.764.764 0 00-.034-.034l-1.859-1.744 2.193-3.29a22.248 22.248 0 013.255-3.851l1.304-1.23zM17.5 8a1.5 1.5 0 11-3 0 1.5 1.5 0 013 0zm-11 13c.9-.9.9-2.6 0-3.5-.9-.9-2.6-.9-3.5 0-1.209 1.209-1.445 3.901-1.49 4.743a.232.232 0 00.247.247c.842-.045 3.534-.281 4.743-1.49z" fill="currentColor" fill-rule="evenodd"></path>
# </svg>
#  2.2K runs
#       </div>
# </div>
# </div>
# </a>]

# %%
def main():
    driver = initialize_driver()
    domain = "https://replicate.com"
    url = '/collections/text-to-image'
    url = f'{domain}{url}'
    soup = goToPage(driver, url)
    time.sleep(10)
    models_list = soup.select('div.grid.grid-cols-1.lg\:grid-cols-2.grid-flow-row.auto-rows-max.gap-8 a')
    
    for model in models_list:
        model_url = f'{domain}{model["href"]}'
        model_soup = goToPage(driver, model_url)
        time.sleep(10)
        model_name = model_soup.select_one('h3').text
        model_description = model_soup.select_one('p.mt-1.max-w-xl').text
        print(model_name, model_description)


    driver.quit()

# %%
main()
# Out:
# stability-ai/
# stable-diffusion
#
#
#
#
#
#
#       A latent text-to-image diffusion model capable of generating photo-realistic images given any text input
#
#
#
#
# stability-ai/
# sdxl
#
#
#
#
#
#
#       A text-to-image generative AI model that creates beautiful images
#
#
#
#
# stability-ai/
# stable-diffusion-inpainting
#
#
#
#
#
#
#       Fill in masked parts of images with Stable Diffusion
#
#
#
#
# ai-forever/
# kandinsky-2.2
#
#
#
#
#
#
#       multilingual text2image latent diffusion model
#
#
#
#
# ai-forever/
# kandinsky-2
#
#
#
#
#
#
#       text2img model trained on LAION HighRes and fine-tuned on internal datasets
#
#
#
#
# fofr/
# sdxl-emoji
#
#
#
#
#
#
#       An SDXL fine-tune based on Apple Emojis
#
#
#
#
# tstramer/
# material-diffusion
#
#
#
#
#
#
#       Stable diffusion fork for generating tileable outputs using v1.5 model
#
#
#
#
# bytedance/
# sdxl-lightning-4step
#
#
#
#
#
#
#       SDXL-Lightning by ByteDance: a fast text-to-image model that makes high-quality images in 4 steps
#
#
#
#
# lucataco/
# ssd-1b
#
#
#
#
#
#
#       Segmind Stable Diffusion Model (SSD-1B) is a distilled 50% smaller version of SDXL, offering a 60% speedup while maintaining high-quality text-to-image generation capabilities
#
#
#
#
# fofr/
# latent-consistency-model
#
#
#
#
#
#
#       Super-fast, 0.6s per image. LCM with img2img, large batching and canny controlnet
#
#
#
#
# batouresearch/
# sdxl-controlnet-lora
#
#
#
#
#
#
#       '''Last update: Now supports img2img.''' SDXL Canny controlnet with LoRA support.
#
#
#
#
# lucataco/
# proteus-v0.2
#
#
#
#
#
#
#       Proteus v0.2 shows subtle yet significant improvements over Version 0.1. It demonstrates enhanced prompt understanding that surpasses MJ6, while also approaching its stylistic capabilities.
#
#
#
#
# playgroundai/
# playground-v2-1024px-aesthetic
#
#
#
#
#
#
#       Playground v2 is a diffusion-based text-to-image generative model trained from scratch by the research team at Playground
#
#
#
#
# lucataco/
# realvisxl-v2.0
#
#
#
#
#
#
#       Implementation of SDXL RealVisXL_V2.0
#
#
#
#
# lucataco/
# realvisxl2-lcm
#
#
#
#
#
#
#       RealvisXL-v2.0 with LCM LoRA - requires fewer steps (4 to 8 instead of the original 40 to 50)
#
#
#
#
# fofr/
# realvisxl-v3-multi-controlnet-lora
#
#
#
#
#
#
#       RealVisXl V3 with multi-controlnet, lora loading, img2img, inpainting
#
#
#
#
# fofr/
# sdxl-multi-controlnet-lora
#
#
#
#
#
#
#       Multi-controlnet, lora loading, img2img, inpainting
#
#
#
#
# fofr/
# sticker-maker
#
#
#
#
#
#
#       Make stickers with AI. Generates graphics with transparent backgrounds.
#
#
#
#
# lucataco/
# dreamshaper-xl-turbo
#
#
#
#
#
#
#       DreamShaper is a general purpose SD model that aims at doing everything well, photos, art, anime, manga. It's designed to match Midjourney and DALL-E.
#
#
#
#
# playgroundai/
# playground-v2.5-1024px-aesthetic
#
#
#
#
#
#
#       Playground v2.5 is the state-of-the-art open-source model in aesthetic quality
#
#
#
#
# fofr/
# any-comfyui-workflow
#
#
#
#
#
#
#       Run any ComfyUI workflow. Guide: https://github.com/fofr/cog-comfyui
#
#
#
#
# ai-forever/
# kandinsky-2-1
#
#
#
#
#
#
#       Kandinsky 2.1 Diffusion Model
#
#
#
#
# lucataco/
# open-dalle-v1.1
#
#
#
#
#
#
#       A unique fusion that showcases exceptional prompt adherence and semantic understanding, it seems to be a step above base SDXL and a step closer to DALLE-3 in terms of prompt comprehension
#
#
#
#
# nightmareai/
# disco-diffusion
#
#
#
#
#
#
#       Generate images using a variety of techniques - Powered by Discoart
#
#
#
#
# lucataco/
# pixart-xl-2
#
#
#
#
#
#
#       PixArt-Alpha 1024px is a transformer-based text-to-image diffusion system trained on text embeddings from T5
#
#
#
#
# adirik/
# realvisxl-v3.0-turbo
#
#
#
#
#
#
#       Photorealism with RealVisXL V3.0 Turbo based on SDXL
#
#
#
#
# lucataco/
# thinkdiffusionxl
#
#
#
#
#
#
#       ThinkDiffusionXL is a go-to model capable of amazing photorealism that's also versatile enough to generate high-quality images across a variety of styles and subjects without needing to be a prompting genius
#
#
#
#
# lucataco/
# proteus-v0.3
#
#
#
#
#
#
#       ProteusV0.3: The Anime Update
#
#
#
#
# artificialguybr/
# nebul.redmond
#
#
#
#
#
#
#       Nebul.Redmond - Stable Diffusion SD XL Finetuned Model
#
#
#
#
# lucataco/
# realistic-vision-v5
#
#
#
#
#
#
#       Realistic Vision v5.0 with VAE
#
#
#
#
# adirik/
# realvisxl-v4.0
#
#
#
#
#
#
#       Photorealism with RealVisXL V4.0
#
#
#
#
# fofr/
# txt2img
#
#
#
#
#
#
#       Many models: RealVisXL, Juggernaut, Proteus, DreamShaper, etc.
#
#
#
#
# adirik/
# kosmos-g
#
#
#
#
#
#
#       Kosmos-G: Generating Images in Context with Multimodal Large Language Models
#
#
#
#
# lucataco/
# sdxl-deepcache
#
#
#
#
#
#
#       SDXL using DeepCache
#
#
#
#
# adirik/
# masactrl-sdxl
#
#
#
#
#
#
#       Editable image generation with MasaCtrl-SDXL
#
#
#
#
# lucataco/
# playground-v2
#
#
#
#
#
#
#       Playground v2 is a diffusion-based text-to-image generative model trained from scratch. Try out all 3 models here

# %%
def get_text_to_image_models(model_soup):
    model_name = model_soup.select_one('h3').text
    model_description = model_soup.select_one('p.mt-1.max-w-xl').text
    model_examples = model_soup.select('div.mb-2lh.h-40.overflow-hidden div img')
    images_src = model_example_images = [img['data-src'] for img in model_examples]


    return model_name, model_description, images_src

# %%
def main():
    driver = initialize_driver()
    domain = "https://replicate.com"
    url = '/collections/text-to-image'
    url = f'{domain}{url}'
    soup = goToPage(driver, url)
    time.sleep(10)
    models_list = soup.select('div.grid.grid-cols-1.lg\:grid-cols-2.grid-flow-row.auto-rows-max.gap-8 a')
    
    for model in models_list:
        model_url = f'{domain}{model["href"]}'
        model_soup = goToPage(driver, model_url)
        time.sleep(10)
        model_name, model_description,images_src = get_text_to_image_models(model_soup)
        model_example_images = ",".join(model_example_images)
        print(model_name, model_description,images_src)

    driver.quit()

# %%
main()
# Out:
# stability-ai/
# stable-diffusion
#
#
#
#
#
#
#       A latent text-to-image diffusion model capable of generating photo-realistic images given any text input
#
#
#      ['https://replicate.delivery/mgxm/980bca24-f8d8-41bb-9f52-fe84bca9c251/out-0.png', 'https://replicate.delivery/mgxm/8d6a8069-b91f-4e61-8136-fa7c0775532c/out-0.png', 'https://replicate.delivery/mgxm/891fd1f9-302e-4d1f-a462-c0c2624ffbca/out-0.png', 'https://replicate.delivery/mgxm/129d24dc-e39e-4240-8978-88420cc1f910/out-0.png', 'https://replicate.delivery/mgxm/4ee3ab76-7864-4604-8897-9d330214d225/out-0.png', 'https://replicate.delivery/mgxm/bb35c491-8794-43d6-81e1-41211831535d/out-0.png', 'https://replicate.delivery/mgxm/0d5e6ce0-dd85-4dd8-a087-a9c59876b456/out-0.png', 'https://replicate.delivery/pbxt/AE5fg6Nbehm5fIkWbIVNsrK1jUEqRr8btVZwoQSEgMemLlpfB/out-0.png', 'https://replicate.delivery/pbxt/Uy5Ma1EruBKkOReB5TwrX9P1ekJjnSftkujvBqkDneSCMywfB/out-0.png', 'https://replicate.delivery/pbxt/aooDunhAPcbUBh979fEblu4qqohEtlG0dPJUf1aLuUkMowCQA/out-0.png', 'https://replicate.delivery/pbxt/2zVI7LtEO0aeKSruhERO0PQCVEsbFivhEyXyR0LDMSg3cYBIA/out-0.png', 'https://replicate.delivery/pbxt/DogdQ8movv5LNlAaHGXrRU9eS1hZMs0OZpIthOsyTbeL6wCQA/out-0.png', 'https://replicate.delivery/pbxt/f4nlztv3uz1iFC4AEf2wBYQGTezdVeysvtZUtwfsvZOJDN6AC/out-0.png', 'https://replicate.delivery/pbxt/XdWzrhW73EIAIxuxl92iE5qVHdiFMnNh3axdwp56EdSGUBCE/out-0.png', 'https://replicate.delivery/pbxt/sWeZFZou6v3CPKuoJbqX46ugPaHT1DcsWYx0srPmGrMOCPYIA/out-0.png']
#
# stability-ai/
# sdxl
#
#
#
#
#
#
#       A text-to-image generative AI model that creates beautiful images
#
#
#      ['https://replicate.delivery/pbxt/V1IpaG4oVXofGyZcPxhhVVfEFvaMx9lMzqR9Fh4RpsRwyyTRA/out-0.png', 'https://replicate.delivery/pbxt/p6Pt5qCuQGYGDxzAbB3goyeFguncwZ8EPj8Ncl7JPhCZa5pIA/out-0.png', 'https://replicate.delivery/pbxt/mBv308Qw3DafE6vOg7a2eNPTDkZMRwRZ5XdDGZzGkdnZ5yTRA/out-0.png', 'https://replicate.delivery/pbxt/cA9288tEJXbcJNBA6OU3gDJ9LWWCFCfDllhoefA8h2VN4lniA/out-0.png', 'https://replicate.delivery/pbxt/YhL0f6v0tfhmlEjce0iA2jFLW5vuKDbUh69FYNjnfQEXhMPFB/out-0.png', 'https://replicate.delivery/pbxt/zIPS4uyGONKvKBg9iTA6FRC785eK7eWhpewpR7W0RnF9rlniA/out-0.png', 'https://replicate.delivery/pbxt/E6Ftpfi0dF1SOi4b6ltUwsfdxUf7zTQSfdhmJfRcfGTdZ88UE/out-0.png', 'https://replicate.delivery/pbxt/NfV2n6S8wBVRekodJQ6QObMKAS5ntznisaIaAi3fVlIY2CoiA/out-0.png', 'https://pbxt.replicate.delivery/YXbcLudoHBIYHV6L0HbcTx5iRzLFMwygLr3vhGpZI35caXbE/out-0.png']
#
# stability-ai/
# stable-diffusion-inpainting
#
#
#
#
#
#
#       Fill in masked parts of images with Stable Diffusion
#
#
#      ['https://replicate.delivery/pbxt/xs0pPOUM6HKmPlJJBXqKfE1YsiMzgNsCuGedlX0VqvPYifLgA/out-0.png']
#
# ai-forever/
# kandinsky-2.2
#
#
#
#
#
#
#       multilingual text2image latent diffusion model
#
#
#      ['https://replicate.delivery/pbxt/Lca3IEjcKoJBBVS6ajROkK37sDzPsmjYxIcFzxPZp65wZzTE/out-0.png', 'https://replicate.delivery/pbxt/2QC5sev3eFg2lUPZrYokF1FYCIGF9YC2BlFtExvMxXKef38EB/out-0.png', 'https://replicate.delivery/pbxt/79ESGrLVzgZyCdfQ4a4o5kJeJbfIOTXTaeuiUItYbEcmC48EB/out-0.png', 'https://replicate.delivery/pbxt/h1FRZp5d5gZfHyyKTA8vJfjAVXbMv4BI5GkkVfVkp1HjMceEB/out-0.png', 'https://replicate.delivery/pbxt/C3TyPTuH1ALBBZ2IcgAcq7H8c2Ednsep2J14EmXyW3WhDnnIA/out-0.png', 'https://replicate.delivery/pbxt/tfZNO0eYA4lLJUKX7ypmgV9tktMCMOQZ682S8zzN3JAvIOPRA/out-0.png', 'https://replicate.delivery/pbxt/CnQ9S5cCxraIHtueXUUEfe4TyQmHmk9CeMx8g9rwpxWFt48EB/out-0.png', 'https://replicate.delivery/pbxt/yllavn6d5pZtIl2X17lkx6MdKVKzAvb8Sp9rWrecUcDvHnnIA/out-0.png']
#
# ai-forever/
# kandinsky-2
#
#
#
#
#
#
#       text2img model trained on LAION HighRes and fine-tuned on internal datasets
#
#
#      ['https://replicate.delivery/pbxt/iQKHCerzd4wEPyRNbJYhTqeKNhRxwqiaYgyLAN09mEaK82wQA/out.png', 'https://replicate.delivery/pbxt/NsOpfQRos43e40IzSq4SY7NTtxGodmSWo1m74K17SVpoUzuQA/out.png', 'https://replicate.delivery/pbxt/2ReXGPtHrE1xe09lakZGFNY6FSdXUOPfSNkw2PAIXAAJ0mdhA/out.png', 'https://replicate.delivery/pbxt/rINssGt0mxrlC5tAXq2o7LGVDBMLe1t1V4UMzSF83g1XxuYIA/out.png', 'https://replicate.delivery/pbxt/4uctuMgkSg7SJt8uaOuvGnSQmKkuEJlClh8pjkRTpc22cXME/out.png', 'https://replicate.delivery/pbxt/jopPv3SSXgorLlN3wuQqsQJUtKetMfiGvyQ1e43d4wi9Q8ihA/out.png']
#
# fofr/
# sdxl-emoji
#
#
#
#
#
#
#       An SDXL fine-tune based on Apple Emojis
#
#
#      ['https://replicate.delivery/pbxt/a3z81v5vwlKfLq1H5uBqpVmkHalOVup0jSLma9E2UaF3tawIA/out-0.png', 'https://replicate.delivery/pbxt/J6vOuC0Yj647JRa9YAUMq1vbGKFAiOreQcKuJmHLI0wQuawIA/out-0.png', 'https://replicate.delivery/pbxt/cNFerMxyBD1UfERJB29hHCGJujf0DShhcDWcaqxlX9aUfVDGB/out-0.png', 'https://replicate.delivery/pbxt/DKFghOgmkTKVCpwgfIeKkTqMemHQMKtW9yxLYqeLyeonHtGMC/out-0.png']
#
# tstramer/
# material-diffusion
#
#
#
#
#
#
#       Stable diffusion fork for generating tileable outputs using v1.5 model
#
#
#      ['https://replicate.delivery/pbxt/XcklpSF1o7Z1I91xQQQHFvJfltWEa3HuQpoeVVTvN7GVJhffA/out-0.png']
#
# bytedance/
# sdxl-lightning-4step
#
#
#
#
#
#
#       SDXL-Lightning by ByteDance: a fast text-to-image model that makes high-quality images in 4 steps
#
#
#      ['https://replicate.delivery/pbxt/R08KPL023tIKO59jt3UnbVYfBIWio8A5b6fz60OL4qLkXRbSA/out-0.png', 'https://replicate.delivery/pbxt/UKMegyLEzeujjEy2cVa2lMJqk9JUHpPu4WgMGLmQVYe8vi2kA/out-0.png', 'https://replicate.delivery/pbxt/JipAbQ9UAnZaAR1dlnf4aYDoOONnCgBtUATVoLUZtsecaRbSA/out-0.png', 'https://replicate.delivery/pbxt/mM4JyYiG2JK0JhBeUJOiafiRcMb6HheewQnEfn4eZLjLuW0mE/out-0.png', 'https://replicate.delivery/pbxt/MkUfpm9XsUXmTSWf4r37w4rpTmXHWlaMKBoO5ElqN9XWbRbSA/out-0.png', 'https://replicate.delivery/pbxt/mgsk9Y7uzU4hCpoLn8kmeIdHVmdfz9b3DBR276mRd8ie4i2kA/out-0.png', 'https://replicate.delivery/pbxt/SJPMy3Y4Yzr4D9CKBvLSDxM1Btf8t1gIbuHzicMFwbZYuoNJA/out-0.png', 'https://replicate.delivery/pbxt/71GWflfTzNqlWkOZh36HgNKx0td7TC27mIHcXKSSNaO5cRbSA/out-0.png', 'https://replicate.delivery/pbxt/8sfPfrww4UmwHkMCxnhXblQ0fg20dHgcBiZTbTdfgMv40FtJB/out-0.png', 'https://replicate.delivery/pbxt/dYdYGKKt04pHJ1kle3eStm3q4mfPiUFlQ5xGeM3mfboYbMPUC/out-0.png']
#
# lucataco/
# ssd-1b
#
#
#
#
#
#
#       Segmind Stable Diffusion Model (SSD-1B) is a distilled 50% smaller version of SDXL, offering a 60% speedup while maintaining high-quality text-to-image generation capabilities
#
#
#      ['https://replicate.delivery/pbxt/J1f6PteWOsvABk0aSrfJtWDZ81pj4JQCKersXkjUe6XIfdYcE/out-0.png', 'https://replicate.delivery/pbxt/e023Do0DaUS9LCWNV0FAonrFbxg7azsnA0jGQPjiKFhW8w4IA/out-0.png', 'https://replicate.delivery/pbxt/oiSJopzGnoIVMJ0YDudEplWaLSrzwFMx4VcOxK1t5qXPew4IA/out-0.png', 'https://replicate.delivery/pbxt/tkLnM18A8fRJEyzpkkYYVdTRSf8HDSL6qozvuK1rf05VyDjjA/out-0.png', 'https://replicate.delivery/pbxt/hM7oIKNVWibYDFY6a8JUfZoz7aJbv8nSAg6eY8ar3jGg5hxRA/out-0.png', 'https://replicate.delivery/pbxt/aPdpZ8LGpBLOEh5yDYr2kMDE9t599ZD7z8aCldcdABzkew4IA/out-0.png', 'https://replicate.delivery/pbxt/l5f9JsytFzQtI66l0iXMOUPVvAvuZJkXHAr0fxbVVl5v6hxRA/out-0.png', 'https://replicate.delivery/pbxt/RpyFfFbZkQ1lLCdOOiMeDpFw7gb93aOAPgooFAfNEQlK2DjjA/out-0.png', 'https://replicate.delivery/pbxt/eK2LWTTri0VBCSpBjLjyDNGVscNsT4wIwuxpl8GOe47w4D2RA/out-0.png', 'https://replicate.delivery/pbxt/3fFKY3MYTIW5eUKEAhgdDP9KrpcBIUokd1ZijW0t7dMeE0sjA/out-1.png']
#
# fofr/
# latent-consistency-model
#
#
#
#
#
#
#       Super-fast, 0.6s per image. LCM with img2img, large batching and canny controlnet
#
#
#      ['https://replicate.delivery/pbxt/gixujfS8h0Q5MyBjEQ1ABVeeHJgs2wcQqZUeEhblne9ntkNOC/out-0.png', 'https://replicate.delivery/pbxt/05gCCuIzueVvKSFILbYlvDdeoDe6CSEERL4yL8QuFcwDeyGHB/out-0.png', 'https://replicate.delivery/pbxt/8c9qee7Ty9oseIwO4l7lrxUM2T7egBs6vOjMUfdEwugFrrNOC/out-3.png', 'https://replicate.delivery/pbxt/w4j2qVhyr7ZNMlospFRwbUjtefYYsBO6uRWIKeW8k0cGfBlHB/out-0.jpg', 'https://replicate.delivery/pbxt/iffO9dQXPphT9kp6zhS1yFIDiFp0rNMyR37ygXsJuNjtS64RA/out-3.png', 'https://replicate.delivery/pbxt/LF23xWrMie2vMCmbiswetET2BLperpEtNodZSN4yNfDkAClHB/out-0.jpg']
#
# batouresearch/
# sdxl-controlnet-lora
#
#
#
#
#
#
#       '''Last update: Now supports img2img.''' SDXL Canny controlnet with LoRA support.
#
#
#      ['https://replicate.delivery/pbxt/oDtYIK2lDoaKMtdE4E5ozQSa61BU3gc4aRvGF3xmFpdwCxbE/out-0.png', 'https://replicate.delivery/pbxt/HniOoHgF6FZeDat536rBTnSIVdEK9EW8j1nvoVSzDTRIbi3IA/out-0.png', 'https://replicate.delivery/pbxt/PT6jEHZpzlbiCdfOtAlcHP4SojSosoPX4p81c0vWheQSQffGB/out-0.png', 'https://replicate.delivery/pbxt/xqJDSe1pbrVPRatKXkTu3CbJj2TQutaeQPxA5UeKlxOv8efNC/out-0.png', 'https://replicate.delivery/pbxt/TgqCZMNv1RJAGNzSLZrFUbbeAyADrvs2dxhIaKStmhTkvfvRA/out-0.png', 'https://replicate.delivery/pbxt/esqC43QNvDzLXqkIl0zAVRLFk53F0NzMJwZ20B9C504SxfvRA/out-0.png']
# lucataco/
# proteus-v0.2
#
#
#
#
#
#
#       Proteus v0.2 shows subtle yet significant improvements over Version 0.1. It demonstrates enhanced prompt understanding that surpasses MJ6, while also approaching its stylistic capabilities.
#
#
#      ['https://replicate.delivery/pbxt/dqkeAQHRwPXJGizilhuDo3riVvx9drRtZvS7tZEEncEXg4HJA/out-0.png', 'https://replicate.delivery/pbxt/eeEXwIMJEmqxE0bPU7boCYuPjg2VfeuSZbiYpBcD4Ff2iIejE/out-0.png', 'https://replicate.delivery/pbxt/TnEt8NNtfM2TEqHziXotLQ2FdCl3LVnPGFzpRc62Ng30h4HJA/out-0.png', 'https://replicate.delivery/pbxt/JzMzVQto8YKVGZKkuJcXTunnLUGfMTyh1hmlOqdmyTaBi4HJA/out-0.png', 'https://replicate.delivery/pbxt/i6EpU6qr5q5SMNUdifqcszKfrz1Uq08NaxnUFOy8fck6JifIB/out-0.png', 'https://replicate.delivery/pbxt/1nrcrEszpsb0Kpv0qNBJrtQjoefjHJ3xSh3whVOJcklSFxPSA/out-0.png', 'https://replicate.delivery/pbxt/qCWYV3GoKBafZisrSXCEOHCl1fQef5fN2Yu9iqEee4L69i4HJA/out-0.png', 'https://replicate.delivery/pbxt/7mGOE7JnYtqaA54YQvnNfsjyRR93RFfpyz1iJMMv7R2RGxPSA/out-0.png', 'https://replicate.delivery/pbxt/h6ZLkuIekuV5TCBHtevG0y5GussQfhPkYyINxCr25FFSNifIB/out-0.png', 'https://replicate.delivery/pbxt/oTXFdefF5mu7SUVWCyp91Rz10H7jvfValfU3G9wdHyOcbEfRC/out-0.png']
#
# playgroundai/
# playground-v2-1024px-aesthetic
#
#
#
#
#
#
#       Playground v2 is a diffusion-based text-to-image generative model trained from scratch by the research team at Playground
#
#
#      ['https://replicate.delivery/pbxt/lQyVYazYu5raGJI4Nrq9lifGkW8foY53PyHYugFuA5Fa7mfjA/out-0.png']
#
# lucataco/
# realvisxl-v2.0
#
#
#
#
#
#
#       Implementation of SDXL RealVisXL_V2.0
#
#
#      ['https://replicate.delivery/pbxt/WRBpX6pWYC6uG57BVF3rgxzvg4U0ZROvngw8CyIpbBOIdAdE/output.png', 'https://replicate.delivery/pbxt/7TKT7Z6GyF77LhefAlIt4tPWHcXAz9nfUfVMJ2NzcUcEZHQHB/output.png', 'https://replicate.delivery/pbxt/swQcxNpx0PY1PNNuMiLvIiXiJzL0K1wLhGUhbUkZtpBrdAdE/output.png', 'https://replicate.delivery/pbxt/eCTbwmWQ00UbQiZdRMfgLhTRIKFUkBPei9fOQ2taGKw3NpaHB/out-0.png', 'https://replicate.delivery/pbxt/L1mPgUU8OPa0EZXHeNnDfrInLTaePMm0DfffggyGTd5SDlqdE/out-0.png', 'https://replicate.delivery/pbxt/6D4sVhRfyVVpfk5o8xbKkhkWrvnGpfCsVBeJaQdZWryJ3EgHB/out-0.png']
#
# lucataco/
# realvisxl2-lcm
#
#
#
#
#
#
#       RealvisXL-v2.0 with LCM LoRA - requires fewer steps (4 to 8 instead of the original 40 to 50)
#
#
#      ['https://replicate.delivery/pbxt/ILTzFdAenk1JLKVb7jZbEDUOUJGz7hSFFSArhCnxin7ICY8IA/out-0.png', 'https://replicate.delivery/pbxt/XH5EVlNNjJ4qBh9AEfMlWEZftdQVJsibqQz1Y509Wgw2Fw4RA/out-0.png', 'https://replicate.delivery/pbxt/IUojxc6ARB4hNNVRDn8eLPdh0GrcRi4Gu11ePPevYe8C0BjHB/out-0.png']
#
# fofr/
# realvisxl-v3-multi-controlnet-lora
#
#
#
#
#
#
#       RealVisXl V3 with multi-controlnet, lora loading, img2img, inpainting
#
#
#      ['https://replicate.delivery/pbxt/0yr4nb3krkIqONe8FNZ4Q0xXZDymwptavRMmdaf9OLNqtcJSA/out-0.png', 'https://replicate.delivery/pbxt/et60juO5esrGAkeXcrnh4vr8bNz28jaacMJeCcxQjXAAG0lIB/out-0.png', 'https://replicate.delivery/pbxt/mUtp8mKk8yI0EJ5olzsnpkeTbAcmy2OTEqnXXc8EFGLhhuEJA/out-0.png', 'https://replicate.delivery/pbxt/Pjd50izNdzJDFJlfczALREnyfGIedK4HufhEVV3tVCK4m0lIB/out-0.png']
#
# fofr/
# sdxl-multi-controlnet-lora
#
#
#
#
#
#
#       Multi-controlnet, lora loading, img2img, inpainting
#
#
#      ['https://replicate.delivery/pbxt/tcEOrqX3qXL9CdCtgpkv5gTzEaAXAOMzlYpDqScfDdQpcS8IA/out-0.png', 'https://replicate.delivery/pbxt/MjfBA747maWhCa2Dc9EHuWY5NDesXzLiMfRMOohzlt2E5PxjA/out-0.png', 'https://replicate.delivery/pbxt/GR5kmreA4fjf9JZIFh0GhIoEGEnJj6SmwYTszYVezXWm7EpHB/out-0.png']
#
# fofr/
# sticker-maker
#
#
#
#
#
#
#       Make stickers with AI. Generates graphics with transparent backgrounds.
#
#
#      ['https://replicate.delivery/pbxt/uMEMjvQNPewQdSebtYhizgWOS3Qdj9o4Fs92g5QZiYt4VkZSA/ComfyUI_00002_.png', 'https://replicate.delivery/pbxt/uzunUrfAUlzLUSHSBqEROF3zZyp8R61enPRZk8MnzMPrYkZSA/ComfyUI_00002_.png', 'https://replicate.delivery/pbxt/IwuKQonhCnYkLx6t4tLvezFFLTfQG54ADBYpyVcWUll3ckZSA/ComfyUI_00002_.png', 'https://replicate.delivery/pbxt/PDxNQhYhWJ7NBdJQuBqggaq88rDeeWVo1rf7L4unwLESfRmJB/ComfyUI_00002_.png', 'https://replicate.delivery/pbxt/NX0pxsueaLxCZKUf3sh9kM5PDPJBHSqoyyELv6DRuHqAhkZSA/ComfyUI_00002_.png', 'https://replicate.delivery/pbxt/Jbn4ks6NwxZZMtx11GiQmfELek5RfezWwcVxxVmAt5t5PSmJB/ComfyUI_00002_.png']
#
# lucataco/
# dreamshaper-xl-turbo
#
#
#
#
#
#
#       DreamShaper is a general purpose SD model that aims at doing everything well, photos, art, anime, manga. It's designed to match Midjourney and DALL-E.
#
#
#      ['https://replicate.delivery/pbxt/VHFfxS2zJYVMVy4Itjzw4ChNdQtEah9wkcUvyPDcPud72eDSA/out-0.png', 'https://replicate.delivery/pbxt/qeEM6A38wmToJiXvehlchEjnshNKYaQ38P3aG4VGdlKei7HkA/out-0.png', 'https://replicate.delivery/pbxt/4TBAecNusNTkXyLiH9a9c0ehJeV7JeoDiLSY0EWfXNa9bufgE/out-0.png', 'https://replicate.delivery/pbxt/u3pfEmHrHj17Vql7qB4oJzOrIQjJhAoQDQsuco0z8ejc09DSA/out-0.png', 'https://replicate.delivery/pbxt/zN4lsQv0j85WL9ix5WIFJ8ed8tIgdkg9jAVmUI1ie3L109DSA/out-0.png', 'https://replicate.delivery/pbxt/4dKymdVMECJHOtUTpsog0Cs1Qymp2NfnhPUpZH2KOT8c8eDSA/out-0.png', 'https://replicate.delivery/pbxt/2dCMrtSwWdJ1DpAjr2B9iG1HTFdiGUk62OTj848VMfJG9eDSA/out-0.png', 'https://replicate.delivery/pbxt/JozcWrqHFpIAHdcswjPfWzU3arftr0HmWUWRT1DMJrxn89DSA/out-0.png']
#
# playgroundai/
# playground-v2.5-1024px-aesthetic
#
#
#
#
#
#
#       Playground v2.5 is the state-of-the-art open-source model in aesthetic quality
#
#
#      ['https://replicate.delivery/pbxt/XAK4XRgpjYaCGRrm9yxzO2bacj4XTE1Nl6bwaXKOHKYApJoE/out-0.png', 'https://replicate.delivery/pbxt/m4yzAf16weulKktxX6vWoYlIzXEVs1K27yzPXKl7fsY8MNBlA/out-0.png', 'https://replicate.delivery/pbxt/JVFYLq2TXT5AGpvNwVAwZ1H09QlCY0YCt2Tu9LcgqS0FqJoE/out-0.png', 'https://replicate.delivery/pbxt/eobr2Btz5X3AUSpwxBumhfHrD4bhbBBPISo9qQAX2zeRSNBlA/out-0.png', 'https://replicate.delivery/pbxt/xGJLmC0sKY4iJ1nh9tcebjIA7GvpJsXG1yMK8rgrUi6uUTQJA/out-0.png', 'https://replicate.delivery/pbxt/xEdAH58WerTcLa20lLvozcZRvpGGiAcPjk33Kfr4Cl52pmgSA/out-0.png', 'https://replicate.delivery/pbxt/owg2QElYfvRiWqpP5vkjpv3831JBbNeR8cGxflMGpTdvVNBlA/out-0.png', 'https://replicate.delivery/pbxt/kf30owjGwXSxCiUPtfJN2pVtaBJtXQFtKSBdy4eofkafI2EUC/out-0.png']
#
# fofr/
# any-comfyui-workflow
#
#
#
#
#
#
#       Run any ComfyUI workflow. Guide: https://github.com/fofr/cog-comfyui
#
#
#      ['https://replicate.delivery/pbxt/6ZSXDOH2AxbeKCho2eLLPi2ynFIvpFMFYjOZudDNhpefFw4IB/ComfyUI_00037_.png', 'https://replicate.delivery/pbxt/MyRv4zkLcZ7jM1QJUZEa7wFMrckKVfPyOSkXJ5age37AmDPSA/ComfyUI_00003_.png', 'https://replicate.delivery/pbxt/GvpKN1SsGJaLBdhZpWyOasslCMq1UeetKDf5l0wshxex5J4IB/ComfyUI_00001_.png', 'https://replicate.delivery/pbxt/V9OGBDeMUMyGfkUzIuhe3jMth0LReJ0YzkNefiYZPiD5DpgjE/ComfyUI_00001_.png', 'https://replicate.delivery/pbxt/itNxPDRjs7IuApmFo6fDxSil8PPSfq6VUcKhCycefomsqKFJB/ComfyUI_00004_.png']
#
# ai-forever/
# kandinsky-2-1
#
#
#
#
#
#
#       Kandinsky 2.1 Diffusion Model
#
#
#      ['https://replicate.delivery/pbxt/aOZ4ywUeyeiyqEz5l7lixq0e5rAbs3qTStetOGXNKZd4g6QEB/out-0.png', 'https://replicate.delivery/pbxt/wgE8IZUFABKpENfbWLEqmlph0rcq89kgY6IVe4aQn345qOERA/out-0.png', 'https://replicate.delivery/pbxt/RW4f5xVr7zSXIC3mqlMT2ip9qv9NgGM2ltzPGXEFZEvLYHiIA/out-0.png']
#
# lucataco/
# open-dalle-v1.1
#
#
#
#
#
#
#       A unique fusion that showcases exceptional prompt adherence and semantic understanding, it seems to be a step above base SDXL and a step closer to DALLE-3 in terms of prompt comprehension
#
#
#      ['https://replicate.delivery/pbxt/7QcJQaHWyoqbDJxOHReq5UtphruA3RfbLvK1NhSYXVq7sXGSA/out-0.png', 'https://replicate.delivery/pbxt/IKGL52sYC35uLNeaMxIffTBweTZLAQJLWJyHYuufwtQyBelhE/out-0.png', 'https://replicate.delivery/pbxt/xFUXm1cNnlKsB1Mb5Hzz5yHEVIAdXEO7g3TZAPxfGZrO3LDJA/out-0.png', 'https://replicate.delivery/pbxt/sxYlUIIf59zYaSz6kqCwfUBJGusZkXPMQ67f1eD6eNua49yQC/out-0.png', 'https://replicate.delivery/pbxt/R80lnepdvTyEAqZFGTeOGyQfRE9WLNfDGFwT5dfzp5lM79yQC/out-0.png', 'https://replicate.delivery/pbxt/wGLUWX389JpLBBOtf6kAS39dSPDcIuMSI3ZlzseeFi9dfeyQC/out-0.png', 'https://replicate.delivery/pbxt/vylSfrDkENRBHKdWy37zS9ZQ2hfrOREGd2g17W8X1OHVyXGSA/out-0.png']
# nightmareai/
# disco-diffusion
#
#
#
#
#
#
#       Generate images using a variety of techniques - Powered by Discoart
#
#
#      ['https://replicate.delivery/mgxm/5800f828-94d5-46a0-9eb2-96b51d7846e3/6af357b1-11dc-4954-ad45-4f17b3bc18890_0.png', 'https://replicate.delivery/mgxm/eb8dc56a-1e37-4e6a-8fd7-51ad12b399f5/ba70ca3b-8ed1-4ac4-a09f-3cc046dd3dea0_0.png', 'https://replicate.delivery/mgxm/357f257e-397a-463f-9c54-561239a9baf0/progress.png', 'https://replicate.delivery/mgxm/38ef3c75-8a67-4b00-829e-b8d4a1e51b16/progress.png', 'https://replicate.delivery/mgxm/36ee41af-46ed-46e4-9f94-15ac3dca5b04/progress.png', 'https://replicate.delivery/mgxm/b7a5a326-55d7-406e-a71a-480db5a49329/f79cddc5-2ed9-4497-a3e4-fe01c89eb2c10_0.png', 'https://replicate.delivery/mgxm/718506fb-f089-4f10-afd0-ba0321a71226/eb1a4d44-6054-4861-8a2e-1d4927542eb20_0.png', 'https://replicate.delivery/mgxm/68db8a8d-bae8-46d3-8ffc-21b7456cc70c/discoart-result.png', 'https://replicate.delivery/mgxm/a5f07613-267a-4ee3-b762-ed4200a64c08/discoart-result.png']
#
# lucataco/
# pixart-xl-2
#
#
#
#
#
#
#       PixArt-Alpha 1024px is a transformer-based text-to-image diffusion system trained on text embeddings from T5
#
#
#      ['https://replicate.delivery/pbxt/nSBVHLqeoD1KECVJ5OJSm90ihtI0zm4qeBvQ9ACZNMQUfg9jA/out-0.png', 'https://replicate.delivery/pbxt/zfT5jSDDvHX2YiOIT1OOMJb0aqzduwIJWuzETmaQqeorfg9jA/out-0.png', 'https://replicate.delivery/pbxt/RQsCybUkaiYHENkiRH9z2w44afGYhJvzYsTANlOWLUWBQYfRA/out-0.png', 'https://replicate.delivery/pbxt/lmskA7wDkp5eEy5sXTxrxldQDi5JengzdrEpPpdEqiMYgwejA/out-0.png', 'https://replicate.delivery/pbxt/r8EVULZz0g7jFdBWRSOkFvKhrejcqcf9GOa5w9BHzO4vgwejA/out-0.png', 'https://replicate.delivery/pbxt/42lazn8cUiYgLp1Nc4iVNmmmgL0VTv35dAs6cBEXfPTgQYfRA/out-0.png', 'https://replicate.delivery/pbxt/VHdtQ5n5ZGaRHh1HlafduJErbG5HScrmiqAxxh5L2A6tQYfRA/out-0.png', 'https://replicate.delivery/pbxt/JxRxoPcFuA7GJtJ7SVNSY7TeUlusgCkgq5iZvi8f4Ai3hwejA/out-0.png', 'https://replicate.delivery/pbxt/HzumMjhDC3I9EFfGnzIR7XkaMJ0meZv8u3CsoqdrqLGamwejA/out-0.png']
#
# adirik/
# realvisxl-v3.0-turbo
#
#
#
#
#
#
#       Photorealism with RealVisXL V3.0 Turbo based on SDXL
#
#
#      ['https://replicate.delivery/pbxt/4MhHPJRLlB65IJPOeJFe3khz5Hn6i5CCrrzCr062Kqns5GHSA/out-0.png', 'https://replicate.delivery/pbxt/L0zA4OSj7U7oOVSwcrVbtaZsXszRYNMTRGltL7KFPBPBvxhE/out-0.png', 'https://replicate.delivery/pbxt/iSXUJ6HfoO2iBK1rUTlz4SKT5SHllnOIanZ2soYRPaC5eGHSA/out-0.png', 'https://replicate.delivery/pbxt/Ziz8oH4wHkIXNd4pnpEYNTSbVgWbMmReNNDxoRdVX5iyfGHSA/out-0.png', 'https://replicate.delivery/pbxt/uVObfqHAH2XfpE4QqO8ex1J9e6UlQvGiLmjRLJxj7u4tEccIB/out-0.png', 'https://replicate.delivery/pbxt/B2UcLdiKDIpqLN2oezfq0It7rLuPz5HlreU7OCPM2xz0IOOkA/out-0.png', 'https://replicate.delivery/pbxt/ewYldosFwO0LZSS2lcz1GAh2vJLrhPFBnIVTDzeLfeKxWccIB/out-0.png', 'https://replicate.delivery/pbxt/IeMgOQo9WbWsVqBEQEp5K1hihSMWmXTkjY26BdhswwneGHHSA/out-0.png', 'https://replicate.delivery/pbxt/dpq1OwVuJsbPClN79ttca0e0I8L8flQWrs7Vumeq6JRVfdcIB/out-0.png']
#
# lucataco/
# thinkdiffusionxl
#
#
#
#
#
#
#       ThinkDiffusionXL is a go-to model capable of amazing photorealism that's also versatile enough to generate high-quality images across a variety of styles and subjects without needing to be a prompting genius
#
#
#      ['https://replicate.delivery/pbxt/mfzcQjPBtjUCMaIKko5AqlwS6DL4VRB8DqBUq1fc8q8Bgy1RA/out-0.png', 'https://replicate.delivery/pbxt/3pVoSLhiux43PVgFwcf4EjxpDLcTDwd1Su1BKfVGDd0Qhy1RA/out-0.png', 'https://replicate.delivery/pbxt/vwOzGP9pWQZ2KFaQ5XBa4axgk5nedsQubF8P8tSpGCuPR56IA/out-0.png', 'https://replicate.delivery/pbxt/uRfY6AaWePqaTEgP1fgtofS0UaOLmyDPbQE8BLHLq0NzMKXHB/out-0.png', 'https://replicate.delivery/pbxt/FZSzRGG3Sh4LIdYvP7s45F9OZ1uSSeSjBecyKOeHfNhAQKXHB/out-0.png', 'https://replicate.delivery/pbxt/DZsOfT2zCmRiDKVssXVAyTyfwuejMrSZnYCZHI0gtvO2IlrjA/out-0.png', 'https://replicate.delivery/pbxt/0Jldb4LnReR1OqXPfuMPFKsuPhDelonuU89w0Q9UVZ4VKlrjA/out-0.png', 'https://replicate.delivery/pbxt/COpuvU8qxIpQGZqxUiBeu4RNwQouQtugNU2N9a0JZjusT56IA/out-0.png']
#
# lucataco/
# proteus-v0.3
#
#
#
#
#
#
#       ProteusV0.3: The Anime Update
#
#
#      ['https://replicate.delivery/pbxt/YQA6VCqkKV5mAVN7O69zBQfAOtvxoIkSTFJ6dfDoMaaY8sWSA/out-0.png', 'https://replicate.delivery/pbxt/KLeR6H1freGlaIRwIOOgDaSSJCG3HHeqiaGY4z8RA1T99zaJB/out-0.png', 'https://replicate.delivery/pbxt/OFTWAMyFi4o2NlyeUy0rbUNMCmTl75iOrFNZ9UGVobbyhWLJA/out-0.png', 'https://replicate.delivery/pbxt/wNNmrQXcTHYRKFGqKDr5pYiQ3BZWJGjvbpzBTUCxQBeCiWLJA/out-0.png', 'https://replicate.delivery/pbxt/ZQbJiK3yDiKoOpHwE7ytoFNjMZXaKCLfYQaU7FU4UWowiWLJA/out-0.png', 'https://replicate.delivery/pbxt/iL2qSzSFkJYKEFOQMZWwSHfYShN9ek3fgCffD42H15FO8o1SC/out-0.png', 'https://replicate.delivery/pbxt/C3LYYa30997dKRdeNDSXNjIK01CH5q8CSto12eWundnPPtWSA/out-0.png']
#
# artificialguybr/
# nebul.redmond
#
#
#
#
#
#
#       Nebul.Redmond - Stable Diffusion SD XL Finetuned Model
#
#
#      ['https://replicate.delivery/pbxt/RekGnfLBwXkQjkgIk7mqxsn41IRtzyV25iZuxQF1k7FYvFPSA/out-0.png', 'https://replicate.delivery/pbxt/dYfykUmdnT3eo055WfdwB1xzWZNykcpn7VrUafcoMwKSAX8IB/out-0.png', 'https://replicate.delivery/pbxt/o92f4eVGSShJd0zZgm6GBARCR4mxOnAv8gYyKgPOKR5T1FPSA/out-0.png']
#
# lucataco/
# realistic-vision-v5
#
#
#
#
#
#
#       Realistic Vision v5.0 with VAE
#
#
#      ['https://replicate.delivery/pbxt/eVMzXJerAzpqnErNJ9P4ncWmd2d3OkGA31DKhG3ElQhLMIbRA/output.png', 'https://replicate.delivery/pbxt/zhhbMtgTSvbcPxmfKXTgdfp8JfT2ipoboY3k7WNOSBKtYQ2iA/output.png', 'https://replicate.delivery/pbxt/ROkdADpHJWKPMJ0L84kv94stpn1wezDDl6AHWMpcLoTOHktIA/output.png', 'https://replicate.delivery/pbxt/ivL2pM53cV5lCRgZt0DvXGVFLYHCLLGmU8mYZitLiiMQDyWE/output.png', 'https://replicate.delivery/pbxt/N8rzYbCKR9JfUqskptrARWub3ZMUfHXfvr0QVA6C59FOdQ2iA/output.png', 'https://replicate.delivery/pbxt/ndPlKkt9G8YSF5dffkJepxylZeevZgBTvfbrKHkex6QzoGktIA/output.png']
#
# adirik/
# realvisxl-v4.0
#
#
#
#
#
#
#       Photorealism with RealVisXL V4.0
#
#
#      ['https://replicate.delivery/pbxt/koQLfGV4o8yWGi4reeIvJQwCxmxrD3S7iQFGre8IfISrpnCTC/out-0.png', 'https://replicate.delivery/pbxt/CHnlYaFyiezoOyC5RS6qHiK6rKpG3KME2e65dpzDFHtJBVYSA/out-0.png', 'https://replicate.delivery/pbxt/qUbpk2lzhgogERLCj9LewhpJ7jNKLYRe2L2mxHdFWZ4AHVYSA/out-0.png', 'https://replicate.delivery/pbxt/mdSJbcSteRwevUIWG1nl5HIPg3DKTtieJxoLAf7JD5eXDpCTC/out-0.png']
#
# fofr/
# txt2img
#
#
#
#
#
#
#       Many models: RealVisXL, Juggernaut, Proteus, DreamShaper, etc.
#
#
#      ['https://replicate.delivery/pbxt/DtFRglJwa5ZwHpvSCnRQmCeLG8EegBNJqkvqXfeFvYIttFAJB/ComfyUI_00001_.png', 'https://replicate.delivery/pbxt/lh2zesQfQfYVdpgbMMckYwRV38UoKuBmHQBrm0YtAwWL4CgkA/ComfyUI_00001_.png', 'https://replicate.delivery/pbxt/HbRFdfTwUehpzkz5dt05TKfyOFJYn1vlWpaTyHP31DZ17CgkA/ComfyUI_00001_.png', 'https://replicate.delivery/pbxt/ZHZLrK2oWr4pJJNKwViZrvh5AZZRH9aGizo4h7hSv1GpXAkE/ComfyUI_00001_.png', 'https://replicate.delivery/pbxt/CLmckHmcxmYiK1s2NIPUVbyG0QoUlliqTR15a1hVjmA0XAkE/ComfyUI_00001_.png', 'https://replicate.delivery/pbxt/6NEahinsakapPd22Nty8YbWkAg2XkjX2ZuiMArD98kZAYAkE/ComfyUI_00001_.png', 'https://replicate.delivery/pbxt/vz723ikfVgzYN6rhoAf9aodgQz4bg3Y4ZaeZE05T8LkeaGAJB/ComfyUI_00001_.png', 'https://replicate.delivery/pbxt/jPiwHtgNYgrFPtoXfJeeWKiDRX6sGfyCp3c8yXEZBobevNASC/ComfyUI_00001_.png']
#
# adirik/
# kosmos-g
#
#
#
#
#
#
#       Kosmos-G: Generating Images in Context with Multimodal Large Language Models
#
#
#      ['https://replicate.delivery/pbxt/M4zXgkAk2fwffpQTCezmUSFkFP0mAi3fZ9jsoUhJtXfyZU9fIA/3.png', 'https://replicate.delivery/pbxt/a7U3sGFJW3p6KRmgoYqoXA4dnvLfPHShGG6HjaG9exJIW1fjA/0.png', 'https://replicate.delivery/pbxt/M44neZC9rowJLicqz3LpmJs0YttYFlLBNuCJteqe7eRf2qefIA/0.png', 'https://replicate.delivery/pbxt/giVQO4P4e3ytFqEfvpBTsik8d09J5fGBjjGNSnF6xFvepVfPC/0.png', 'https://replicate.delivery/pbxt/aYXKkkuCWM6WN96DfeKBlVFTle875XmLLmMkJFp7rkNryqfHB/0.png']
#
# lucataco/
# sdxl-deepcache
#
#
#
#
#
#
#       SDXL using DeepCache
#
#
#      ['https://replicate.delivery/pbxt/cj5eFwQqZPwROSKox75sbAVEJvfs58GX2Tswlu5tYzWwdLKSA/out-0.png', 'https://replicate.delivery/pbxt/IUWpr8ucslbkLdhfncYwTLEznv2krfs2k6HuwZ9EkWUCcLKSA/out-0.png']
# adirik/
# masactrl-sdxl
#
#
#
#
#
#
#       Editable image generation with MasaCtrl-SDXL
#
#
#      ['https://replicate.delivery/pbxt/09z14i0H7QZhDtBvCnC1WtH05GpU60ZEliQ3ZNRW4WqEf9fRA/output1.png', 'https://replicate.delivery/pbxt/ZtU07fpeetaX3pDadmb8SeJiA6c60vHnkS7LVWQvAQUX2vfPC/output1.png', 'https://replicate.delivery/pbxt/qGH8xiD4Iq4jFZeoNcqEdgacBvCukPn1IK7Ut2c7zn9sCefjA/output2.png']
#
# lucataco/
# playground-v2
#
#
#
#
#
#
#       Playground v2 is a diffusion-based text-to-image generative model trained from scratch. Try out all 3 models here
#
#
#      ['https://replicate.delivery/pbxt/BdCKezxEeWgtLEtRdeCKrgyMg6ekeEFv8XYcM1khNUfgf1ffjA/out-0.png', 'https://replicate.delivery/pbxt/hYCK3SZHofQWbaoxXf4kLIpBNURfZ1PiVFVSb1pIKpP3AAAkA/out-0.png', 'https://replicate.delivery/pbxt/iLeSMF1WWQSkDKMgpMe02uccP5VHOepEC2G3dexSdek9YBAQC/out-0.png']

# %%
import mysql.connector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10976/1725300336.py in <module>
# ----> 1 import mysql.connector
#
# ModuleNotFoundError: No module named 'mysql'

# %%
pip install mysql
# Out:
# Collecting mysql
#   Downloading mysql-0.0.3-py3-none-any.whl (1.2 kB)
# Collecting mysqlclient
#   Downloading mysqlclient-2.2.4-cp39-cp39-win_amd64.whl (203 kB)
# Installing collected packages: mysqlclient, mysql
# Successfully installed mysql-0.0.3 mysqlclient-2.2.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-8.3.0-cp39-cp39-win_amd64.whl (15.4 MB)
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-8.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
def init_db():
    try:
        conn = mysql.connector.connect(
            host="localhost",
            user="root",
            password="",
            database="replicate"
        )

        cursor = conn.cursor()

        create_table_query = """CREATE TABLE IF NOT EXISTS models (
            id INT AUTO_INCREMENT PRIMARY KEY,
            name VARCHAR(255) NOT NULL,
            description TEXT NOT NULL,
            image TEXT NOT NULL
        )"""

        cursor.execute(create_table_query)

        conn.commit()

        return conn

    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
def insert_model(engine, model_name, model_description, model_example_images):
    try:
        query = f"INSERT INTO models (name, description, image) VALUES ('{model_name}', '{model_description}', '{model_example_images}')"
        cursor = engine.cursor()    
        cursor.execute(query)
        engine.commit()
        cursor.close()
        print(f"Model {model_name} inserted successfully")
    except Exception as e:
        print(f"Error: {e}")
        engine.rollback()
    finally:
        cursor.close()
        engine.close()

# %%
def main():
    driver = initialize_driver()
    domain = "https://replicate.com"
    url = '/collections/text-to-image'
    url = f'{domain}{url}'
    soup = goToPage(driver, url)
    time.sleep(10)
    models_list = soup.select('div.grid.grid-cols-1.lg\:grid-cols-2.grid-flow-row.auto-rows-max.gap-8 a')
    
    for model in models_list:
        model_url = f'{domain}{model["href"]}'
        model_soup = goToPage(driver, model_url)
        time.sleep(10)
        model_name, model_description, model_example_images = get_text_to_image_models(model_soup)
        model_example_images = ",".join(model_example_images)
        engine = init_db()
        print(model_example_images)
        #insert_model(engine, model_name, model_description, model_example_images)


    driver.quit()

# %%
main()
# Out:
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 6
# https://replicate.delivery/mgxm/980bca24-f8d8-41bb-9f52-fe84bca9c251/out-0.png,https://replicate.delivery/mgxm/8d6a8069-b91f-4e61-8136-fa7c0775532c/out-0.png,https://replicate.delivery/mgxm/891fd1f9-302e-4d1f-a462-c0c2624ffbca/out-0.png,https://replicate.delivery/mgxm/129d24dc-e39e-4240-8978-88420cc1f910/out-0.png,https://replicate.delivery/mgxm/4ee3ab76-7864-4604-8897-9d330214d225/out-0.png,https://replicate.delivery/mgxm/bb35c491-8794-43d6-81e1-41211831535d/out-0.png,https://replicate.delivery/mgxm/0d5e6ce0-dd85-4dd8-a087-a9c59876b456/out-0.png,https://replicate.delivery/pbxt/AE5fg6Nbehm5fIkWbIVNsrK1jUEqRr8btVZwoQSEgMemLlpfB/out-0.png,https://replicate.delivery/pbxt/Uy5Ma1EruBKkOReB5TwrX9P1ekJjnSftkujvBqkDneSCMywfB/out-0.png,https://replicate.delivery/pbxt/aooDunhAPcbUBh979fEblu4qqohEtlG0dPJUf1aLuUkMowCQA/out-0.png,https://replicate.delivery/pbxt/2zVI7LtEO0aeKSruhERO0PQCVEsbFivhEyXyR0LDMSg3cYBIA/out-0.png,https://replicate.delivery/pbxt/DogdQ8movv5LNlAaHGXrRU9eS1hZMs0OZpIthOsyTbeL6wCQA/out-0.png,https://replicate.delivery/pbxt/f4nlztv3uz1iFC4AEf2wBYQGTezdVeysvtZUtwfsvZOJDN6AC/out-0.png,https://replicate.delivery/pbxt/XdWzrhW73EIAIxuxl92iE5qVHdiFMnNh3axdwp56EdSGUBCE/out-0.png,https://replicate.delivery/pbxt/sWeZFZou6v3CPKuoJbqX46ugPaHT1DcsWYx0srPmGrMOCPYIA/out-0.png
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 6
# https://replicate.delivery/pbxt/V1IpaG4oVXofGyZcPxhhVVfEFvaMx9lMzqR9Fh4RpsRwyyTRA/out-0.png,https://replicate.delivery/pbxt/p6Pt5qCuQGYGDxzAbB3goyeFguncwZ8EPj8Ncl7JPhCZa5pIA/out-0.png,https://replicate.delivery/pbxt/mBv308Qw3DafE6vOg7a2eNPTDkZMRwRZ5XdDGZzGkdnZ5yTRA/out-0.png,https://replicate.delivery/pbxt/cA9288tEJXbcJNBA6OU3gDJ9LWWCFCfDllhoefA8h2VN4lniA/out-0.png,https://replicate.delivery/pbxt/YhL0f6v0tfhmlEjce0iA2jFLW5vuKDbUh69FYNjnfQEXhMPFB/out-0.png,https://replicate.delivery/pbxt/zIPS4uyGONKvKBg9iTA6FRC785eK7eWhpewpR7W0RnF9rlniA/out-0.png,https://replicate.delivery/pbxt/E6Ftpfi0dF1SOi4b6ltUwsfdxUf7zTQSfdhmJfRcfGTdZ88UE/out-0.png,https://replicate.delivery/pbxt/NfV2n6S8wBVRekodJQ6QObMKAS5ntznisaIaAi3fVlIY2CoiA/out-0.png,https://pbxt.replicate.delivery/YXbcLudoHBIYHV6L0HbcTx5iRzLFMwygLr3vhGpZI35caXbE/out-0.png
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 6
# https://replicate.delivery/pbxt/xs0pPOUM6HKmPlJJBXqKfE1YsiMzgNsCuGedlX0VqvPYifLgA/out-0.png
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 6
# https://replicate.delivery/pbxt/Lca3IEjcKoJBBVS6ajROkK37sDzPsmjYxIcFzxPZp65wZzTE/out-0.png,https://replicate.delivery/pbxt/2QC5sev3eFg2lUPZrYokF1FYCIGF9YC2BlFtExvMxXKef38EB/out-0.png,https://replicate.delivery/pbxt/79ESGrLVzgZyCdfQ4a4o5kJeJbfIOTXTaeuiUItYbEcmC48EB/out-0.png,https://replicate.delivery/pbxt/h1FRZp5d5gZfHyyKTA8vJfjAVXbMv4BI5GkkVfVkp1HjMceEB/out-0.png,https://replicate.delivery/pbxt/C3TyPTuH1ALBBZ2IcgAcq7H8c2Ednsep2J14EmXyW3WhDnnIA/out-0.png,https://replicate.delivery/pbxt/tfZNO0eYA4lLJUKX7ypmgV9tktMCMOQZ682S8zzN3JAvIOPRA/out-0.png,https://replicate.delivery/pbxt/CnQ9S5cCxraIHtueXUUEfe4TyQmHmk9CeMx8g9rwpxWFt48EB/out-0.png,https://replicate.delivery/pbxt/yllavn6d5pZtIl2X17lkx6MdKVKzAvb8Sp9rWrecUcDvHnnIA/out-0.png
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 6
# https://replicate.delivery/pbxt/iQKHCerzd4wEPyRNbJYhTqeKNhRxwqiaYgyLAN09mEaK82wQA/out.png,https://replicate.delivery/pbxt/NsOpfQRos43e40IzSq4SY7NTtxGodmSWo1m74K17SVpoUzuQA/out.png,https://replicate.delivery/pbxt/2ReXGPtHrE1xe09lakZGFNY6FSdXUOPfSNkw2PAIXAAJ0mdhA/out.png,https://replicate.delivery/pbxt/rINssGt0mxrlC5tAXq2o7LGVDBMLe1t1V4UMzSF83g1XxuYIA/out.png,https://replicate.delivery/pbxt/4uctuMgkSg7SJt8uaOuvGnSQmKkuEJlClh8pjkRTpc22cXME/out.png,https://replicate.delivery/pbxt/jopPv3SSXgorLlN3wuQqsQJUtKetMfiGvyQ1e43d4wi9Q8ihA/out.png
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 6
# https://replicate.delivery/pbxt/a3z81v5vwlKfLq1H5uBqpVmkHalOVup0jSLma9E2UaF3tawIA/out-0.png,https://replicate.delivery/pbxt/J6vOuC0Yj647JRa9YAUMq1vbGKFAiOreQcKuJmHLI0wQuawIA/out-0.png,https://replicate.delivery/pbxt/cNFerMxyBD1UfERJB29hHCGJujf0DShhcDWcaqxlX9aUfVDGB/out-0.png,https://replicate.delivery/pbxt/DKFghOgmkTKVCpwgfIeKkTqMemHQMKtW9yxLYqeLyeonHtGMC/out-0.png
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 6
# https://replicate.delivery/pbxt/XcklpSF1o7Z1I91xQQQHFvJfltWEa3HuQpoeVVTvN7GVJhffA/out-0.png
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 6
# https://replicate.delivery/pbxt/R08KPL023tIKO59jt3UnbVYfBIWio8A5b6fz60OL4qLkXRbSA/out-0.png,https://replicate.delivery/pbxt/UKMegyLEzeujjEy2cVa2lMJqk9JUHpPu4WgMGLmQVYe8vi2kA/out-0.png,https://replicate.delivery/pbxt/JipAbQ9UAnZaAR1dlnf4aYDoOONnCgBtUATVoLUZtsecaRbSA/out-0.png,https://replicate.delivery/pbxt/mM4JyYiG2JK0JhBeUJOiafiRcMb6HheewQnEfn4eZLjLuW0mE/out-0.png,https://replicate.delivery/pbxt/MkUfpm9XsUXmTSWf4r37w4rpTmXHWlaMKBoO5ElqN9XWbRbSA/out-0.png,https://replicate.delivery/pbxt/mgsk9Y7uzU4hCpoLn8kmeIdHVmdfz9b3DBR276mRd8ie4i2kA/out-0.png,https://replicate.delivery/pbxt/SJPMy3Y4Yzr4D9CKBvLSDxM1Btf8t1gIbuHzicMFwbZYuoNJA/out-0.png,https://replicate.delivery/pbxt/71GWflfTzNqlWkOZh36HgNKx0td7TC27mIHcXKSSNaO5cRbSA/out-0.png,https://replicate.delivery/pbxt/8sfPfrww4UmwHkMCxnhXblQ0fg20dHgcBiZTbTdfgMv40FtJB/out-0.png,https://replicate.delivery/pbxt/dYdYGKKt04pHJ1kle3eStm3q4mfPiUFlQ5xGeM3mfboYbMPUC/out-0.png
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 6
# https://replicate.delivery/pbxt/J1f6PteWOsvABk0aSrfJtWDZ81pj4JQCKersXkjUe6XIfdYcE/out-0.png,https://replicate.delivery/pbxt/e023Do0DaUS9LCWNV0FAonrFbxg7azsnA0jGQPjiKFhW8w4IA/out-0.png,https://replicate.delivery/pbxt/oiSJopzGnoIVMJ0YDudEplWaLSrzwFMx4VcOxK1t5qXPew4IA/out-0.png,https://replicate.delivery/pbxt/tkLnM18A8fRJEyzpkkYYVdTRSf8HDSL6qozvuK1rf05VyDjjA/out-0.png,https://replicate.delivery/pbxt/hM7oIKNVWibYDFY6a8JUfZoz7aJbv8nSAg6eY8ar3jGg5hxRA/out-0.png,https://replicate.delivery/pbxt/aPdpZ8LGpBLOEh5yDYr2kMDE9t599ZD7z8aCldcdABzkew4IA/out-0.png,https://replicate.delivery/pbxt/l5f9JsytFzQtI66l0iXMOUPVvAvuZJkXHAr0fxbVVl5v6hxRA/out-0.png,https://replicate.delivery/pbxt/RpyFfFbZkQ1lLCdOOiMeDpFw7gb93aOAPgooFAfNEQlK2DjjA/out-0.png,https://replicate.delivery/pbxt/eK2LWTTri0VBCSpBjLjyDNGVscNsT4wIwuxpl8GOe47w4D2RA/out-0.png,https://replicate.delivery/pbxt/3fFKY3MYTIW5eUKEAhgdDP9KrpcBIUokd1ZijW0t7dMeE0sjA/out-1.png
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 6
# https://replicate.delivery/pbxt/gixujfS8h0Q5MyBjEQ1ABVeeHJgs2wcQqZUeEhblne9ntkNOC/out-0.png,https://replicate.delivery/pbxt/05gCCuIzueVvKSFILbYlvDdeoDe6CSEERL4yL8QuFcwDeyGHB/out-0.png,https://replicate.delivery/pbxt/8c9qee7Ty9oseIwO4l7lrxUM2T7egBs6vOjMUfdEwugFrrNOC/out-3.png,https://replicate.delivery/pbxt/w4j2qVhyr7ZNMlospFRwbUjtefYYsBO6uRWIKeW8k0cGfBlHB/out-0.jpg,https://replicate.delivery/pbxt/iffO9dQXPphT9kp6zhS1yFIDiFp0rNMyR37ygXsJuNjtS64RA/out-3.png,https://replicate.delivery/pbxt/LF23xWrMie2vMCmbiswetET2BLperpEtNodZSN4yNfDkAClHB/out-0.jpg
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 6
# https://replicate.delivery/pbxt/oDtYIK2lDoaKMtdE4E5ozQSa61BU3gc4aRvGF3xmFpdwCxbE/out-0.png,https://replicate.delivery/pbxt/HniOoHgF6FZeDat536rBTnSIVdEK9EW8j1nvoVSzDTRIbi3IA/out-0.png,https://replicate.delivery/pbxt/PT6jEHZpzlbiCdfOtAlcHP4SojSosoPX4p81c0vWheQSQffGB/out-0.png,https://replicate.delivery/pbxt/xqJDSe1pbrVPRatKXkTu3CbJj2TQutaeQPxA5UeKlxOv8efNC/out-0.png,https://replicate.delivery/pbxt/TgqCZMNv1RJAGNzSLZrFUbbeAyADrvs2dxhIaKStmhTkvfvRA/out-0.png,https://replicate.delivery/pbxt/esqC43QNvDzLXqkIl0zAVRLFk53F0NzMJwZ20B9C504SxfvRA/out-0.png
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 6
# https://replicate.delivery/pbxt/dqkeAQHRwPXJGizilhuDo3riVvx9drRtZvS7tZEEncEXg4HJA/out-0.png,https://replicate.delivery/pbxt/eeEXwIMJEmqxE0bPU7boCYuPjg2VfeuSZbiYpBcD4Ff2iIejE/out-0.png,https://replicate.delivery/pbxt/TnEt8NNtfM2TEqHziXotLQ2FdCl3LVnPGFzpRc62Ng30h4HJA/out-0.png,https://replicate.delivery/pbxt/JzMzVQto8YKVGZKkuJcXTunnLUGfMTyh1hmlOqdmyTaBi4HJA/out-0.png,https://replicate.delivery/pbxt/i6EpU6qr5q5SMNUdifqcszKfrz1Uq08NaxnUFOy8fck6JifIB/out-0.png,https://replicate.delivery/pbxt/1nrcrEszpsb0Kpv0qNBJrtQjoefjHJ3xSh3whVOJcklSFxPSA/out-0.png,https://replicate.delivery/pbxt/qCWYV3GoKBafZisrSXCEOHCl1fQef5fN2Yu9iqEee4L69i4HJA/out-0.png,https://replicate.delivery/pbxt/7mGOE7JnYtqaA54YQvnNfsjyRR93RFfpyz1iJMMv7R2RGxPSA/out-0.png,https://replicate.delivery/pbxt/h6ZLkuIekuV5TCBHtevG0y5GussQfhPkYyINxCr25FFSNifIB/out-0.png,https://replicate.delivery/pbxt/oTXFdefF5mu7SUVWCyp91Rz10H7jvfValfU3G9wdHyOcbEfRC/out-0.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10976/451043146.py in <module>
# ----> 1 main()
#
# ~\AppData\Local\Temp/ipykernel_10976/2834056986.py in main()
#      10     for model in models_list:
#      11         model_url = f'{domain}{model["href"]}'
# ---> 12         model_soup = goToPage(driver, model_url)
#      13         time.sleep(10)
#      14         model_name, model_description, model_example_images = get_text_to_image_models(model_soup)
#
# ~\AppData\Local\Temp/ipykernel_10976/3354868239.py in goToPage(driver, url)
#       1 def goToPage(driver, url):
#       2     driver.get(url)
# ----> 3     time.sleep(5)
#       4     body = driver.find_element(By.TAG_NAME, 'body')
#       5     soup = BeautifulSoup(body.get_attribute('innerHTML'), 'html.parser')
#
# KeyboardInterrupt:

# %%
def get_text_to_image_models(model_soup):
    model_name = model_soup.select_one('h3').text
    model_description = model_soup.select_one('p.mt-1.max-w-xl').text.strip()
    model_examples = model_soup.select('div.mb-2lh.h-40.overflow-hidden div img')
    images_src = model_example_images = [img['data-src'] for img in model_examples]
    return model_name, model_description, images_src

# %%
def main():
    driver = initialize_driver()
    domain = "https://replicate.com"
    url = '/collections/text-to-image'
    url = f'{domain}{url}'
    soup = goToPage(driver, url)
    time.sleep(10)
    models_list = soup.select('div.grid.grid-cols-1.lg\:grid-cols-2.grid-flow-row.auto-rows-max.gap-8 a')
    
    for model in models_list:
        model_url = f'{domain}{model["href"]}'
        model_soup = goToPage(driver, model_url)
        time.sleep(10)

        model_name, model_description, model_example_images = get_text_to_image_models(model_soup)
        model_example_images = ",".join(model_example_images)
        engine = init_db()
        insert_model(engine, model_name, model_description, model_example_images)


    driver.quit()

# %%
main()
# Out:
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 6
# Error: 'NoneType' object has no attribute 'cursor'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10976/3514565724.py in insert_model(engine, model_name, model_description, model_example_images)
#       3         query = f"INSERT INTO models (name, description, image) VALUES ('{model_name}', '{model_description}', '{model_example_images}')"
# ----> 4         cursor = engine.cursor()
#       5         cursor.execute(query)
#
# AttributeError: 'NoneType' object has no attribute 'cursor'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10976/3514565724.py in insert_model(engine, model_name, model_description, model_example_images)
#      10         print(f"Error: {e}")
# ---> 11         engine.rollback()
#      12     finally:
#
# AttributeError: 'NoneType' object has no attribute 'rollback'
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10976/451043146.py in <module>
# ----> 1 main()
#
# ~\AppData\Local\Temp/ipykernel_10976/3530157330.py in main()
#      16         model_example_images = ",".join(model_example_images)
#      17         engine = init_db()
# ---> 18         insert_model(engine, model_name, model_description, model_example_images)
#      19
#      20
#
# ~\AppData\Local\Temp/ipykernel_10976/3514565724.py in insert_model(engine, model_name, model_description, model_example_images)
#      11         engine.rollback()
#      12     finally:
# ---> 13         cursor.close()
#      14         engine.close()
#      15
#
# UnboundLocalError: local variable 'cursor' referenced before assignment

# %%
def insert_model(engine, model_name, model_description, model_example_images):
    try:
        query = f"INSERT INTO models (name, description, image) VALUES ('{model_name}', '{model_description}', '{model_example_images}')"
        cursor = engine.cursor()    
        cursor.execute(query)
        engine.commit()
        cursor.close()
        print(f"Model {model_name} inserted successfully")
    except Exception as e:
        print(f"Error: {e}")
        engine.rollback()
    finally:
        cursor.close()
        engine.close()

# %%
def init_db():
    try:
        conn = mysql.connector.connect(
            host="localhost",
            user="root",
            password="",
            database="replicate"
        )

        cursor = conn.cursor()

        create_table_query = """CREATE TABLE IF NOT EXISTS models (
            id INT AUTO_INCREMENT PRIMARY KEY,
            name VARCHAR(255) NOT NULL,
            description TEXT NOT NULL,
            image TEXT NOT NULL
        )"""

        cursor.execute(create_table_query)

        conn.commit()

        return conn

    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
main()
# Out:
# Model
# stability-ai/
# stable-diffusion
#
#
#
#
#  inserted successfully
# Model
# stability-ai/
# sdxl
#
#
#
#
#  inserted successfully
# Exception ignored in: <function Service.__del__ at 0x0000024D83485550>
# Traceback (most recent call last):
#   File "C:\Users\Cloud\anaconda3\lib\site-packages\selenium\webdriver\common\service.py", line 189, in __del__
#     self.stop()
#   File "C:\Users\Cloud\anaconda3\lib\site-packages\selenium\webdriver\common\service.py", line 146, in stop
#     self.send_remote_shutdown_command()
#   File "C:\Users\Cloud\anaconda3\lib\site-packages\selenium\webdriver\common\service.py", line 131, in send_remote_shutdown_command
#     if not self.is_connectable():
#   File "C:\Users\Cloud\anaconda3\lib\site-packages\selenium\webdriver\common\service.py", line 120, in is_connectable
#     return utils.is_connectable(self.port)
#   File "C:\Users\Cloud\anaconda3\lib\site-packages\selenium\webdriver\common\utils.py", line 101, in is_connectable
#     socket_ = socket.create_connection((host, port), 1)
#   File "C:\Users\Cloud\anaconda3\lib\socket.py", line 832, in create_connection
#     sock.connect(sa)
# KeyboardInterrupt:
# Model
# stability-ai/
# stable-diffusion-inpainting
#
#
#
#
#  inserted successfully
# Model
# ai-forever/
# kandinsky-2.2
#
#
#
#
#  inserted successfully
# Model
# ai-forever/
# kandinsky-2
#
#
#
#
#  inserted successfully
# Model
# fofr/
# sdxl-emoji
#
#
#
#
#  inserted successfully
# Model
# tstramer/
# material-diffusion
#
#
#
#
#  inserted successfully
# Model
# bytedance/
# sdxl-lightning-4step
#
#
#
#
#  inserted successfully
# Model
# lucataco/
# ssd-1b
#
#
#
#
#  inserted successfully
# Model
# fofr/
# latent-consistency-model
#
#
#
#
#  inserted successfully
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'Last update: Now supports img2img.''' SDXL Canny controlnet with LoRA support.',' at line 8
# Model
# lucataco/
# proteus-v0.2
#
#
#
#
#  inserted successfully
# Model
# playgroundai/
# playground-v2-1024px-aesthetic
#
#
#
#
#  inserted successfully
# Model
# lucataco/
# realvisxl-v2.0
#
#
#
#
#  inserted successfully
# Model
# lucataco/
# realvisxl2-lcm
#
#
#
#
#  inserted successfully
# Model
# fofr/
# realvisxl-v3-multi-controlnet-lora
#
#
#
#
#  inserted successfully
# Model
# fofr/
# sdxl-multi-controlnet-lora
#
#
#
#
#  inserted successfully
# Model
# fofr/
# sticker-maker
#
#
#
#
#  inserted successfully
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 's designed to match Midjourney and DALL-E.', 'https://replicate.delivery/pbxt/VH' at line 8
# Model
# playgroundai/
# playground-v2.5-1024px-aesthetic
#
#
#
#
#  inserted successfully
# Model
# fofr/
# any-comfyui-workflow
#
#
#
#
#  inserted successfully
# Model
# ai-forever/
# kandinsky-2-1
#
#
#
#
#  inserted successfully
# Model
# lucataco/
# open-dalle-v1.1
#
#
#
#
#  inserted successfully
# Model
# nightmareai/
# disco-diffusion
#
#
#
#
#  inserted successfully
# Model
# lucataco/
# pixart-xl-2
#
#
#
#
#  inserted successfully
# Model
# adirik/
# realvisxl-v3.0-turbo
#
#
#
#
#  inserted successfully
# Error: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 's also versatile enough to generate high-quality images across a variety of styl' at line 8
# Model
# lucataco/
# proteus-v0.3
#
#
#
#
#  inserted successfully
# Model
# artificialguybr/
# nebul.redmond
#
#
#
#
#  inserted successfully
# Model
# lucataco/
# realistic-vision-v5
#
#
#
#
#  inserted successfully
# Model
# adirik/
# realvisxl-v4.0
#
#
#
#
#  inserted successfully
# Model
# fofr/
# txt2img
#
#
#
#
#  inserted successfully
# Model
# adirik/
# kosmos-g
#
#
#
#
#  inserted successfully
# Model
# lucataco/
# sdxl-deepcache
#
#
#
#
#  inserted successfully
# Model
# adirik/
# masactrl-sdxl
#
#
#
#
#  inserted successfully
# Model
# lucataco/
# playground-v2
#
#
#
#
#  inserted successfully

# %%
def generate_image(prompt):
    driver = initialize_driver()
    domain = "https://replicate.com"
    url = '/collections/text-to-image'
    url = f'{domain}{url}'
    soup = goToPage(driver, url)
    time.sleep(10)
    models_list = soup.select('div.grid.grid-cols-1.lg\:grid-cols-2.grid-flow-row.auto-rows-max.gap-8 a')
    
    for model in models_list:
        model_url = f'{domain}{model["href"]}'
        model_soup = goToPage(driver, model_url)
        prompt_input = driver.find_element(By.ID, 'prompt')
        prompt_input.clear()
        if prompt_input:
            
            prompt_input.send_keys(prompt)
            time.sleep(5)
            generate_button = driver.find_element(By.CSS_SELECTOR , 'button[type="submit"]')
            generate_button.click()
            time.sleep(10)
            output_image = driver.find_element(By.CSS_SELECTOR, '[data-testid="value-output-image"]')  
            image_url = output_image.get_attribute('src')
            download_image(image_url, "output/")
            print(f"Image generated successfully for model {model['href']}")
    driver.quit()

# %%
def download_image(image_url, output_dir):
    try:
        response = requests.get(image_url)
        image_name = image_url.split("/")[-1] + "-" + str(time.time())
        with open(f'{output_dir}{image_name}', 'wb') as image_file:
            image_file.write(response.content)
        print(f"Image {image_name} downloaded successfully")
    except Exception as e:
        print(f"Error: {e}")
        print(f"Error downloading image {image_url}")

# %%
generate_image("Paris in a sunny day")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10976/4110673163.py in <module>
# ----> 1 generate_image("Paris in a sunny day")
#
# ~\AppData\Local\Temp/ipykernel_10976/3811924141.py in generate_image(prompt)
#      20             generate_button.click()
#      21             time.sleep(10)
# ---> 22             output_image = driver.find_element(By.CSS_SELECTOR, '[data-testid="value-output-image"]')
#      23             image_url = output_image.get_attribute('src')
#      24             download_image(image_url, "output/")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     739             value = f'[name="{value}"]'
#     740
# --> 741         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     742
#     743     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     345         response = self.command_executor.execute(driver_command, params)
#     346         if response:
# --> 347             self.error_handler.check_response(response)
#     348             response["value"] = self._unwrap_value(response.get("value", None))
#     349             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[data-testid="value-output-image"]"}
#   (Session info: chrome=123.0.6312.86); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00DE4CC3+225091]
# 	(No symbol) [0x00D14E11]
# 	(No symbol) [0x00BB9A7A]
# 	(No symbol) [0x00BF175B]
# 	(No symbol) [0x00BF188B]
# 	(No symbol) [0x00C27882]
# 	(No symbol) [0x00C0F5A4]
# 	(No symbol) [0x00C25CB0]
# 	(No symbol) [0x00C0F2F6]
# 	(No symbol) [0x00BE79B9]
# 	(No symbol) [0x00BE879D]
# 	sqlite3_dbdata_init [0x01259A63+4064547]
# 	sqlite3_dbdata_init [0x0126106A+4094762]
# 	sqlite3_dbdata_init [0x0125B968+4072488]
# 	sqlite3_dbdata_init [0x00F5C9C9+930953]
# 	(No symbol) [0x00D207E4]
# 	(No symbol) [0x00D1AD08]
# 	(No symbol) [0x00D1AE31]
# 	(No symbol) [0x00D0CAA0]
# 	BaseThreadInitThunk [0x75CBFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x776B7C5E+286]
# 	RtlGetAppContainerNamedObjectPath [0x776B7C2E+238]
